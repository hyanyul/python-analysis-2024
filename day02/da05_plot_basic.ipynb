# %% [markdown]
# ## Matplotlib 학습
#
# ### Matplotlib
# 파이썬 시각화 라이브러리. 다양한 차트 생성가능
#
# #### Matplotlib 설치
# ```python
# !pip install matplotlib
# ```

# %%
# 설치
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.49.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      --------- ----------------------------- 41.0/162.3 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 3.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\dev\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\dev\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\dev\python312\lib\site-packages (from matplotlib) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dev\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\dev\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.3-cp312-cp312-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.6 MB 9.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/7.6 MB 11.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/7.6 MB 13.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.6 MB 16.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.6/7.6 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.6 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 25.7 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 25.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 19.5 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.7 kB ? eta -:--:--
#    --------------------------------------- 187.7/187.7 kB 11.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 67.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 34.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 pyparsing-3.1.2

# %% [markdown]
# #### Matplotlib 사용
# ```python
# import matplotlib.pyplot as plt
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## 단일차트
plt.plot([1, 2, 3, 4, 5])
plt.show()  # [<matplotlib.lines.Line2D at 0x2082e7b8d70>] 와 같은 객체 정보 출력이 사라짐

# %%
plt.plot(np.random.randn(50))   # np.random.randn(n) = n개의 정수를 랜덤하게 만들어 줌
plt.show()

# %%
## 다중차트, figure() 사용
fig = plt.figure()
plt1 = fig.add_subplot(2, 2, 1) #1번 차트
plt2 = fig.add_subplot(2, 2, 2) #2번 차트
plt3 = fig.add_subplot(2, 2, 3) #3번 차트
plt4 = fig.add_subplot(2, 2, 4) #4번 차트

plt1.plot(np.random.randn(50))
plt2.hist(np.random.randn(100))
plt3.scatter(np.arange(30), np.random.randn(30))
plt4.plot(np.random.randn(30), 'violet')    #색상 'r', 'g', 'b', 'y', 'violet'

plt.show()

# %%
#다중차트 2번째, 4개 이상 가능
fig, axes = plt.subplots(2, 2)
axes[0][0].plot(np.random.randn(50))
axes[0][1].hist(np.random.randn(100))
axes[1][0].scatter(np.arange(30), np.random.randn(30))
axes[1][1].plot(np.random.randn(30), 'pink')


plt.show()
