# %% [markdown]
# ## 빅데이터 실습
#
# ### 데이터 포털 Open API 활용
#
# #### 데이터 수집
#
# ##### Open API
# - 한국관광공사 관광빅데이터 정보 서비스 GW
#     - 기본 URL: http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?
#     - 서비스키: u%2BQmmPpDuWqY3YCYyNdT3lbrkMqLKmY4ZGt3Lu53w5SLeN6acxyqypza9nj6Kh5Kbt3le9DvchPjNpd5NOiW7g%3D%3D
#     - 파라미터(? 뒤)
#         - serviceKey = 본인 서비스키(encoding)
#         - numOfRows = 한 페이지에 나타낼 결과 수(기본: 10 / 60으로 하면 하루치 전부 다 가져올 수 있음)
#         - pageNo = 페이지 번호(기본: 1)
#         - MobileOS = IOS, AND, WIN, ETC(기타) (모바일 운영체제)
#         - MobileApp = AppTest
#         - startYmd = 시작일자
#         - endYmd = 종료일자

# %%
# 필요 라이브러리 사용 등록
import requests
import json
import xmltodict
import pandas as pd

# %% [markdown]
# ##### 추가 모듈
# - XML을 딕셔너리로 한번 바꿔주는 모듈
# - xmltodict
#
# ```
# !pip install xmltodict
# ```

# %%
# !!pip install xmltodict
# Out:
# ['Collecting xmltodict',
#  '  Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)',
#  'Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)',
#  'Installing collected packages: xmltodict',
#  'Successfully installed xmltodict-0.13.0']

# %%
# 서비스키
serviceKey = r'u%2BQmmPpDuWqY3YCYyNdT3lbrkMqLKmY4ZGt3Lu53w5SLeN6acxyqypza9nj6Kh5Kbt3le9DvchPjNpd5NOiW7g%3D%3D'

# %%
# 기준날짜
ymd = '20231201'

# %%
# 필요 URL 생성
baseUrl = 'http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?'
parameter = 'numOfRows=60&pageNo=1&MobileOS=ETC&MobileApp=AppTest&' +\
            f'serviceKey={serviceKey}&startYmd={ymd}&endYmd={ymd}'
totalUrl = baseUrl + parameter
totalUrl
# Out:
# 'http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?numOfRows=60&pageNo=1&MobileOS=ETC&MobileApp=AppTest&serviceKey=u%2BQmmPpDuWqY3YCYyNdT3lbrkMqLKmY4ZGt3Lu53w5SLeN6acxyqypza9nj6Kh5Kbt3le9DvchPjNpd5NOiW7g%3D%3D&startYmd=20231201&endYmd=20231201'

# %%
# 실행 테스트
# res.status_code: 200(OK) or 404/500 | res.text(str) | res.content(byte)
res = requests.get(totalUrl)
res.status_code
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header>\n  <resultCode>0000</resultCode>\n  <resultMsg>OK</resultMsg>\n</header><body><items>\n  <item>\n    <areaCode>11</areaCode>\n    <areaNm>서울특별시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>1</touDivCd>\n    <touDivNm>현지인(a)</touDivNm>\n    <touNum>4603042.5</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>11</areaCode>\n    <areaNm>서울특별시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>2</touDivCd>\n    <touDivNm>외지인(b)</touDivNm>\n    <touNum>1448384.0</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>11</areaCode>\n    <areaNm>서울특별시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>3</touDivCd>\n    <touDivNm>외국인(c)</touDivNm>\n    <touNum>30583.54999999999</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>26</areaCode>\n    <areaNm>부산광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>1</touDivCd>\n    <touDivNm>현지인(a)</touDivNm>\n    <touNum>1583729.0</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>26</areaCode>\n    <areaNm>부산광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>2</touDivCd>\n    <touDivNm>외지인(b)</touDivNm>\n    <touNum>323697.5</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>26</areaCode>\n    <areaNm>부산광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>3</touDivCd>\n    <touDivNm>외국인(c)</touDivNm>\n    <touNum>8219.360000000004</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>27</areaCode>\n    <areaNm>대구광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>1</touDivCd>\n    <touDivNm>현지인(a)</touDivNm>\n    <touNum>1206880.5</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>27</areaCode>\n    <areaNm>대구광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>2</touDivCd>\n    <touDivNm>외지인(b)</touDivNm>\n    <touNum>238301.0</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>27</areaCode>\n    <areaNm>대구광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>3</touDivCd>\n    <touDivNm>외국인(c)</touDivNm>\n    <touNum>1004.25</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>28</areaCode>\n    <areaNm>인천광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>1</touDivCd>\n    <touDivNm>현지인(a)</touDivNm>\n    <touNum>1364107.5</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>28</areaCode>\n    <areaNm>인천광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>2</touDivCd>\n    <touDivNm>외지인(b)</touDivNm>\n    <touNum>384289.5</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>28</areaCode>\n    <areaNm>인천광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>3</touDivCd>\n    <touDivNm>외국인(c)</touDivNm>\n    <touNum>21739.42000000001</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>29</areaCode>\n    <areaNm>광주광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>1</touDivCd>\n    <touDivNm>현지인(a)</touDivNm>\n    <touNum>698495.0</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>29</areaCode>\n    <areaNm>광주광역시</areaNm>\n    <daywkDivCd>5</daywkDivCd>\n    <daywkDivNm>금요일</daywkDivNm>\n    <touDivCd>2</touDivCd>\n    <touDivNm>외지인(b)</touDivNm>\n    <touNum>157787.0</touNum>\n    <baseYmd>20231201</baseYmd>\n  </item>\n  <item>\n    <areaCode>29</areaCode>\n   ...

# %%
# open api로 넘어온 text(xml 타입)
# xmltodict.parse()로 받아온 xml 문서를 파이썬 dictionary타입으로 변환
# json.dumps()로 dictionary를 json타입으로 변환
# json.dumps(xmltodict.parse(res.text))
dictTemp = xmltodict.parse(res.text)

# %%
dictTemp['response']['header']['resultCode']    # 0000 = ok
# Out:
# '0000'

# %%
# 딕셔너리의 키를 []에 추가해서 원하는 데이터까지 내려가야 함
dictTemp['response']['body']['items']['item']

# %%
# 필요한 값 추출
pd.DataFrame(dictTemp['response']['body']['items']['item'])
# Out:
#    areaCode   areaNm daywkDivCd daywkDivNm touDivCd touDivNm  \
# 0        11    서울특별시          5        금요일        1   현지인(a)
# 1        11    서울특별시          5        금요일        2   외지인(b)
# 2        11    서울특별시          5        금요일        3   외국인(c)
# 3        26    부산광역시          5        금요일        1   현지인(a)
# 4        26    부산광역시          5        금요일        2   외지인(b)
# 5        26    부산광역시          5        금요일        3   외국인(c)
# 6        27    대구광역시          5        금요일        1   현지인(a)
# 7        27    대구광역시          5        금요일        2   외지인(b)
# 8        27    대구광역시          5        금요일        3   외국인(c)
# 9        28    인천광역시          5        금요일        1   현지인(a)
# 10       28    인천광역시          5        금요일        2   외지인(b)
# 11       28    인천광역시          5        금요일        3   외국인(c)
# 12       29    광주광역시          5        금요일        1   현지인(a)
# 13       29    광주광역시          5        금요일        2   외지인(b)
# 14       29    광주광역시          5        금요일        3   외국인(c)
# 15       30    대전광역시          5        금요일        1   현지인(a)
# 16       30    대전광역시          5        금요일        2   외지인(b)
# 17       30    대전광역시          5        금요일        3   외국인(c)
# 18       31    울산광역시          5        금요일        1   현지인(a)
# 19       31    울산광역시          5        금요일        2   외지인(b)
# 20       31    울산광역시          5        금요일        3   외국인(c)
# 21       36  세종특별자치시          5        금요일        1   현지인(a)
# 22       36  세종특별자치시          5        금요일        2   외지인(b)
# 23       36  세종특별자치시          5        금요일        3   외국인(c)
# 24       41      경기도          5        금요일        1   현지인(a)
# 25       41      경기도          5        금요일        2   외지인(b)
# 26       41      경기도          5        금요일        3   외국인(c)
# 27       43     충청북도          5        금요일        1   현지인(a)
# 28       43     충청북도          5        금요일        2   외지인(b)
# 29       43     충청북도          5        금요일        3   외국인(c)
# 30       44     충청남도          5        금요일        1   현지인(a)
# 31       44     충청남도          5        금요일        2   외지인(b)
# 32       44     충청남도          5        금요일        3   외국인(c)
# 33       45     전라북도          5        금요일        1   현지인(a)
# 34       45     전라북도          5        금요일        2   외지인(b)
# 35       45     전라북도          5        금요일        3   외국인(c)
# 36       46     전라남도          5        금요일        1   현지인(a)
# 37       46     전라남도          5        금요일        2   외지인(b)
# 38       46     전라남도          5        금요일        3   외국인(c)
# 39       47     경상북도          5        금요일        1   현지인(a)
# 40       47     경상북도          5        금요일        2   외지인(b)
# 41       47     경상북도          5        금요일        3   외국인(c)
# 42       48     경상남도          5        금요일        1   현지인(a)
# 43       48     경상남도          5        금요일        2   외지인(b)
# 44       48     경상남도          5        금요일        3   외국인(c)
# 45       50  제주특별자치도          5        금요일        1   현지인(a)
# 46       50  제주특별자치도          5        금요일        2   외지인(b)
# 47       50  제주특별자치도          5        금요일        3   외국인(c)
# 48       51  강원특별자치도          5        금요일        1   현지인(a)
# 49       51  강원특별자치도          5        금요일        2   외지인(b)
# 50       51  강원특별자치도          5        금요일        3   외국인(c)
#
#                 touNum   baseYmd
# 0            4603042.5  20231201
# 1            1448384.0  20231201
# 2    30583.54999999999  20231201
# 3            1583729.0  20231201
# 4             323697.5  20231201
# 5    8219.360000000004  20231201
# 6            1206880.5  20231201
# 7             238301.0  20231201
# 8              1004.25  20231201
# 9            1364107.5  20231201
# 10            384289.5  20231201
# 11   21739.42000000001  20231201
# 12            698495.0  20231201
# 13            157787.0  20231201
# 14              331.34  20231201
# 15            738927.0  20231201
# 16            187705.0  20231201
# 17   555.7399999999999  20231201
# 18            579222.0  20231201
# 19            100565.5  20231201
# 20  1168.1399999999994  20231201
# 21            196077.0  20231201
# 22             61694.5  20231201
# 23  115.53999999999999  20231201
# 24           6727591.5  20231201
# 25           1321565.0  20231201
# 26  12889.719999999994  20231201
# 27            832072.5  20231201
# 28            222694.5  20231201
# 29   923.7600000000002  20231201
# 30           1138844.0  20231201
# 31            319809.0  20231201
# 32   2219.960000000001  20231201
# 33           1046790.5  20231201
# 34            201036.5  20231201
# 35  1097.6699999999998  20231201
# 36           1028951.0  20231201
# 37            250631.5  20231201
# 38  2576.0100000000016  20231201
# 39           1429491.0  20231201
# 40            345768.5  20231201
# 41  1558.5399999999988  20231201
# 42           1769103.0  20231201
# 43            309358.0  20231201
# 44   3939.319999999998  20231201
# 45            575680.0  20231201
# 46            123858.0  20231201
# 47   4765.650000000001  20231201
# 48           1062414.5  20231201
# 49            262528.0  20231201
# 50  1774.8699999999997  20231201

# %% [markdown]
# ##### 단일테스트 완료 / 함수 생성
# - getRequestUrl()
# - getTouristDataService()
# - 2023.12.01~2023.12.31 반복문으로 처리

# %%
# 웹으로 OpenApi url 호출하는 함수
def getRequestUrl(url):
    try:
        res = requests.get(url, verify=False)
        if res.status_code == 200:   # 요청결과 OK
            return res.text
    except Exception as e:
        print(f'getRequestUrl() 호출 예외 발생: {e}')
        return None

# %%
# Open API 호출함수
def getTouristDataService(ymd):
    serviceKey = r'u%2BQmmPpDuWqY3YCYyNdT3lbrkMqLKmY4ZGt3Lu53w5SLeN6acxyqypza9nj6Kh5Kbt3le9DvchPjNpd5NOiW7g%3D%3D'
    baseUrl = 'http://apis.data.go.kr/B551011/DataLabService/metcoRegnVisitrDDList?'
    parameter = 'numOfRows=60&pageNo=1&MobileOS=ETC&MobileApp=AppTest&' +\
            f'serviceKey={serviceKey}&startYmd={ymd}&endYmd={ymd}'
    totalUrl = baseUrl + parameter
    
    result = getRequestUrl(totalUrl)
    if result == None:
        return None
    else:
        return result

# %%
# 실행테스트
data = getTouristDataService('20231202')

# %%
# xml을 딕셔너리롸 형변환 후 필요한 데이터까지만 추출
xmltodict.parse(data)['response']['body']['items']['item']
# Out:
# [{'areaCode': '11',
#   'areaNm': '서울특별시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '4085018.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '11',
#   'areaNm': '서울특별시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '1940487.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '11',
#   'areaNm': '서울특별시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '31302.643199999977',
#   'baseYmd': '20231202'},
#  {'areaCode': '26',
#   'areaNm': '부산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1479635.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '26',
#   'areaNm': '부산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '484620.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '26',
#   'areaNm': '부산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '8319.971599999999',
#   'baseYmd': '20231202'},
#  {'areaCode': '27',
#   'areaNm': '대구광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1137794.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '27',
#   'areaNm': '대구광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '371346.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '27',
#   'areaNm': '대구광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '968.3136999999996',
#   'baseYmd': '20231202'},
#  {'areaCode': '28',
#   'areaNm': '인천광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1284664.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '28',
#   'areaNm': '인천광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '576121.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '28',
#   'areaNm': '인천광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '22231.714000000014',
#   'baseYmd': '20231202'},
#  {'areaCode': '29',
#   'areaNm': '광주광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '655350.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '29',
#   'areaNm': '광주광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '234832.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '29',
#   'areaNm': '광주광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '316.67550000000006',
#   'baseYmd': '20231202'},
#  {'areaCode': '30',
#   'areaNm': '대전광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '666823.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '30',
#   'areaNm': '대전광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '294675.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '30',
#   'areaNm': '대전광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '453.0054000000001',
#   'baseYmd': '20231202'},
#  {'areaCode': '31',
#   'areaNm': '울산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '535377.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '31',
#   'areaNm': '울산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '145684.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '31',
#   'areaNm': '울산광역시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '1181.1516999999997',
#   'baseYmd': '20231202'},
#  {'areaCode': '36',
#   'areaNm': '세종특별자치시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '176176.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '36',
#   'areaNm': '세종특별자치시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '85393.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '36',
#   'areaNm': '세종특별자치시',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '129.39999999999998',
#   'baseYmd': '20231202'},
#  {'areaCode': '41',
#   'areaNm': '경기도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '6267723.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '41',
#   'areaNm': '경기도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '1935661.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '41',
#   'areaNm': '경기도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '11546.321200000002',
#   'baseYmd': '20231202'},
#  {'areaCode': '43',
#   'areaNm': '충청북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '752342.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '43',
#   'areaNm': '충청북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '333392.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '43',
#   'areaNm': '충청북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '850.9209000000002',
#   'baseYmd': '20231202'},
#  {'areaCode': '44',
#   'areaNm': '충청남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1021212.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '44',
#   'areaNm': '충청남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '516285.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '44',
#   'areaNm': '충청남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '1839.4372000000005',
#   'baseYmd': '20231202'},
#  {'areaCode': '45',
#   'areaNm': '전라북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '960242.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '45',
#   'areaNm': '전라북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '321156.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '45',
#   'areaNm': '전라북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '1081.6135000000004',
#   'baseYmd': '20231202'},
#  {'areaCode': '46',
#   'areaNm': '전라남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '940555.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '46',
#   'areaNm': '전라남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '393193.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '46',
#   'areaNm': '전라남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '3582.448700000002',
#   'baseYmd': '20231202'},
#  {'areaCode': '47',
#   'areaNm': '경상북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1315552.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '47',
#   'areaNm': '경상북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '560462.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '47',
#   'areaNm': '경상북도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '1473.5511999999992',
#   'baseYmd': '20231202'},
#  {'areaCode': '48',
#   'areaNm': '경상남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '1642364.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '48',
#   'areaNm': '경상남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '485761.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '48',
#   'areaNm': '경상남도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '4137.968900000001',
#   'baseYmd': '20231202'},
#  {'areaCode': '50',
#   'areaNm': '제주특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '564287.5',
#   'baseYmd': '20231202'},
#  {'areaCode': '50',
#   'areaNm': '제주특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '135870.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '50',
#   'areaNm': '제주특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '6044.297500000002',
#   'baseYmd': '20231202'},
#  {'areaCode': '51',
#   'areaNm': '강원특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '961401.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '51',
#   'areaNm': '강원특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '438060.0',
#   'baseYmd': '20231202'},
#  {'areaCode': '51',
#   'areaNm': '강원특별자치도',
#   'daywkDivCd': '6',
#   'daywkDivNm': '토요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '1362.5706999999995',
#   'baseYmd': '20231202'}]

# %%
# 추가 라이브러리 사용 등록
from tqdm import tqdm
import time

# %%
# 반복문으로 처리
totalList = []
year = 2023
month = 12
for day in tqdm(range(1, 32)):
    reqYmd = f'{year}{month}{day:02d}'
    data = getTouristDataService(reqYmd)
    if xmltodict.parse(data)['response']['body']['items'] == None:   #해당날짜에 데이터 없을 수 있음
        resList = []
    else:
        resList = xmltodict.parse(data)['response']['body']['items']['item']
    totalList = totalList + resList
# Out:
# 100%|██████████| 31/31 [01:25<00:00,  2.75s/it]

# %%
len(totalList)
# Out:
# 1530

# %%
dfTourist = pd.DataFrame(totalList)

# %%
dfTourist
# Out:
#      areaCode   areaNm daywkDivCd daywkDivNm touDivCd touDivNm  \
# 0          11    서울특별시          5        금요일        1   현지인(a)
# 1          11    서울특별시          5        금요일        2   외지인(b)
# 2          11    서울특별시          5        금요일        3   외국인(c)
# 3          26    부산광역시          5        금요일        1   현지인(a)
# 4          26    부산광역시          5        금요일        2   외지인(b)
# ...       ...      ...        ...        ...      ...      ...
# 1525       51  강원특별자치도          7        일요일        2   외지인(b)
# 1526       51  강원특별자치도          7        일요일        3   외국인(c)
# 1527       52  전북특별자치도          7        일요일        1   현지인(a)
# 1528       52  전북특별자치도          7        일요일        2   외지인(b)
# 1529       52  전북특별자치도          7        일요일        3   외국인(c)
#
#                   touNum   baseYmd
# 0              4603042.5  20231201
# 1              1448384.0  20231201
# 2      30583.54999999999  20231201
# 3              1583729.0  20231201
# 4               323697.5  20231201
# ...                  ...       ...
# 1525            694498.0  20231231
# 1526  2551.5179999999996  20231231
# 1527            910780.5  20231231
# 1528            408299.5  20231231
# 1529  1043.7619000000004  20231231
#
# [1530 rows x 8 columns]

# %%
dfTourist.info()
