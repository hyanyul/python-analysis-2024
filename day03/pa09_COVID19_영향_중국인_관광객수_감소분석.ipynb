# %% [markdown]
# ## 빅데이터 실습
#
# ### COVID19, 코로나 바이러스의 영향으로 중국인 관광객이 얼마나 줄었을까?
#
# #### 데이터 수집
# - 한국관광공사, [한국관광 데이터랩 데이터](https://datalab.visitkorea.or.kr/datalab/portal/main/getMainForm.do)
#
# #### 데이터 로드 및 전처리
# - 분석 전 가장 중요한 단계, 데이터 분석의 8할은 데이터 전처리임
# - Data processing: 분석에 적합하도록 원하는(쉬운) 형태로 데이터를 가공하는 과정
#     - 결측치 처리(데이터 없는 것, None/Null/NaN), 이상치 처리(범위 벗어난 데이터), 변수 정규화, 파생변수 생성 등
#
# ##### 엑셀파일 로드

# %%
#Pandas 사용 등록
import pandas as pd

# %%
kto_201901 = pd.read_excel('./data/kto_201901.xlsx', header=1, usecols='A:G', skipfooter=4)
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계
# 0      아시아주  765082  10837  1423  14087  125521  916950
# 1        일본  198805   2233   127    785    4576  206526
# 2        대만   86393     74    22    180    1285   87954
# 3        홍콩   34653     59     2     90    1092   35896
# 4       마카오    2506      2     0     17      45    2570
# ..      ...     ...    ...   ...    ...     ...     ...
# 62  아프리카 기타     768    718    90    206     908    2690
# 63     기타대륙      33      4     0      1      16      54
# 64     국적미상      33      4     0      1      16      54
# 65     교포소계       0      0     0      0   15526   15526
# 66       교포       0      0     0      0   15526   15526
#
# [67 rows x 7 columns]

# %%
kto_201901.head()   #제일 위 5개 나옴
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계
# 0  아시아주  765082  10837  1423  14087  125521  916950
# 1    일본  198805   2233   127    785    4576  206526
# 2    대만   86393     74    22    180    1285   87954
# 3    홍콩   34653     59     2     90    1092   35896
# 4   마카오    2506      2     0     17      45    2570

# %%
kto_201901.tail()   #제일 아래 5개 나옴
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %% [markdown]
# ##### 데이터 탐색(전처리 위함)

# %%
#Dataframe(DF) 정보 개요
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
#DF 통계치 확인
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
#한 번도 한국에 방문한 적 없는 대륙, 나라(목적별)
#문자열 / 논리 연산 여러줄 작성 시 \(역슬래시) 붙여줘야 함
condition = ((kto_201901['관광'] == 0) | (kto_201901['상용'] == 0) | \
            (kto_201901['공용'] == 0) | (kto_201901['유학/연수'] == 0))

# %%
kto_201901[condition]
kto_201901.style.background_gradient(axis=None, vmin=0, vmax=200_000, cmap='Yn')  #vmax: 기준 최대값
# Out:
# <style type="text/css">
# #T_67ce8_row0_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_67ce8_row0_col2, #T_67ce8_row0_col4, #T_67ce8_row7_col1, #T_67ce8_row7_col5, #T_67ce8_row8_col1, #T_67ce8_row27_col5, #T_67ce8_row28_col6, #T_67ce8_row50_col1, #T_67ce8_row56_col1, #T_67ce8_row56_col6, #T_67ce8_row57_col1, #T_67ce8_row57_col6, #T_67ce8_row65_col5, #T_67ce8_row65_col6, #T_67ce8_row66_col5, #T_67ce8_row66_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# ...
