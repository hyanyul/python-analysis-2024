# %% [markdown]
# ## 빅데이터 실습
#
# ### 제주도 핫플레이스 시각화
#
# #### 데이터 불러오기

# %%
# 필요 라이브러리 사용 등록
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster    # 마커클러스터용 클래스 추가

# %%
# 추가 라이브러리 사용 등록
import requests
import time
from tqdm import tqdm

# %%
#불필요한 경고 메시지 제거
import warnings
warnings.filterwarnings('ignore')

# %%
#한글 깨짐 문제 해결

from matplotlib import rcParams, font_manager, rc

font_path = 'C:/Windows/Fonts/NanumGothicCoding.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()  
rc('font', family=font)
rcParams['axes.unicode_minus'] = False

# %%
# 데이터 불러오기
rawTotal = pd.read_excel('../day04/data/1_crawling_raw.xlsx')
rawTotal.tail()
# Out:
#                                                 content        date like  \
# 8796  Now it's purple😆💜수색 넘 이쀼리 🤭 올해는 아퓨지말구 즐거운 일만 가...  2019-01-01   42
# 8797  .간다간다간다#제주 #친정여행 #겨울방학 #제주여행앞머리는 괜히 전날 잘라서 또순이...  2019-01-01   50
# 8798  2019년 모두 복 많이많이 받고 풍요로운 한해 보내길 ♥️#사진좀찍으시는님덕에건져...  2019-01-01   68
# 8799  2018.12.25 ⠀룸에 의자가 두개 밖에 없어서 ⠀이현이는 유모차에 앉아서 식사...  2019-01-01   70
# 8800  .2019년 첫날디스이즈핫에서 새해를 맞이하시는 손님들께 떡국을 준비했습니다.한 해...  2019-01-01   48
#
#       place                                               tags
# 8796    NaN  ['#일상', '#구기자', '#티타임', '#2019', '#새해', '#차스타그...
# 8797    NaN  ['#제주', '#친정여행', '#겨울방학', '#제주여행앞머리는', '#친정찬스'...
# 8798   Jeju                         ['#사진좀찍으시는님덕에건져또', '#이순간']
# 8799    NaN                                                 []
# 8800  디스이즈핫                          ['#HappyNewYearEveryone']

# %%
# 위치 정보 확인
locCounts = rawTotal['place'].value_counts()

# %%
locCounts.head()
# Out:
# place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59
# Name: count, dtype: int64

# %%
# DF로 변경
dfLocCounts = pd.DataFrame(locCounts)
dfLocCounts.head(3)
# Out:
#                       count
# place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108

# %%
dfLocCounts.to_excel('./data/3_location_counts.xlsx')

# %%
Locations = list(dfLocCounts.index)
Locations
# Out:
# ['Jeju',
#  'Jeju-do',
#  'Jungle Book by Alice',
#  'Seogwipo',
#  '제주도 크리스마스 박물관',
#  '할로비치',
#  '제주에인감귤밭',
#  'Jeju Island',
#  '성산일출봉 城山日出峰  Seongsan Ilchulbong',
#  '폼포코식당_pompokokitchen',
#  '1100고지',
#  'Nimome',
#  '월정리해변',
#  '고집돌우럭중문점',
#  '석부작박물관',
#  '제주도 애월읍',
#  '알뜨르 비행장',
#  '카멜리아 힐',
#  '제주레포츠랜드',
#  '밥깡패',
#  '제주 함덕 서우봉 해변',
#  '제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地',
#  '제주고궁한복카페 jeju gogung hanbok studio',
#  '위미동백나무군락지',
#  '제주신화월드 Jeju Shinhwa World',
#  'Woljeongri Beach',
#  '협재해변 Beach',
#  '연동 바오젠 거리',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '고래배꼽',
#  '제주 성산 신산포구자연산횟집 회포장',
#  '새별오름',
#  '용머리해안',
#  '용눈이오름',
#  '캔디원',
#  '사려니숲길',
#  '하이엔드 제주',
#  '제주빅볼랜드',
#  '서귀포 느영나영 게스트하우스',
#  '휴애리 자연생활공원',
#  '옹포리',
#  '삼무공원',
#  '마마뜰',
#  '제주어린왕자게스트하우스',
#  '위미동백나무군락',
#  '제주커피박물관 Baum',
#  'Jeju Aewol',
#  '한라산',
#  '위미2리 동백군락지',
#  'Jeju Island 제주특별자치도 济州道',
#  '광치기해변',
#  '서우봉',
#  '제주해남',
#  '한라산 (漢拏山, Hallasan)',
#  '카페한라산',
#  '성이시돌목장',
#  '제주 송악산',
#  '옹포별장가든',
#  '월정리카페콧수염',
#  '牛岛 Udo Island 우도',
#  '곽지해수욕장',
#  '카페브리프',
#  '아줄레주',
#  '에코랜드',
#  '산굼부리',
#  '제주 꿈꾸는고래 스쿠버&게스트하우스',
#  'Terarosa - 테라로사',
#  'Casa Linda Guesthouse-까사 린다 펜션',
#  '고집돌우럭-gozipfish',
#  'the cliff jeju - 더클리프 제주',
#  '세화해수욕장',
#  '디저트쌀롱 톨',
#  '번개과학체험관',
#  'Hidden Cliff / 히든 클리프',
#  '오전열한시',
#  '하도핑크',
#  '오후새우시',
#  '르페도라펜션',
#  '제주 협재 해수욕장',
#  '소세지가게',
#  '면차롱',
#  '제주신라호텔',
#  '친봉산장',
#  '오설록티뮤지엄',
#  '주상절리대',
#  '로타리과자점',
#  '르토아베이스먼트',
#  '비자림',
#  '노라바',
#  '퍼시픽랜드 - Pacific Land JEJU',
#  '제주동문재래시장',
#  '우아당',
#  '우드노트',
#  'LOTTE Hotel Jeju 롯데호텔제주',
#  '춘심이네 본점',
#  '서귀포 매일올레시장',
#  '함덕487',
#  '녹근로33',
#  'Paris, France',
#  '명월국민학교',
#  '커피캄머',
#  '남원큰엉해안경승지',
#  '아날로그감귤체험',
#  '탐라반상',
#  '플레이스 캠프 제주',
#  '만월당',
#  '성산일출봉 게스트하우스 파티 띵까게스트하우스',
#  'Busan, South Korea',
#  '새별오름 (Saebyul Orum)',
#  '해발1950m 한라산 백록담',
#  '제주도',
#  '수목원테마파크',
#  'Hidden Cliff Hotel & Nature',
#  '지금이순간카페',
#  '제주꿈꾸는고래',
#  'Jungmun Beach',
#  'Sunnyside Beachclub Jeju',
#  'The Shilla Jeju',
#  '함덕반하다',
#  'Jeju International Airport',
#  '몽상드 애월 (Mônsant)',
#  '하늘아래 게스트하우스',
#  '서귀포항',
#  '명랑스낵',
#  '제주여행',
#  '붉은제주',
#  '아뜰리에안',
#  '푸른섬 제주도',
#  "블레블랑제리 Ble' Boulangerie",
#  '설심당본점',
#  '한라수목원',
#  '제주도 월정리',
#  '앙뚜아네트',
#  '안녕김녕sea',
#  '돈사돈',
#  'Jeju horse Riding farm',
#  '다람쥐식탁',
#  '환상의 섬 Jeju Island',
#  '쿠주',
#  '제주국제공항',
#  '커피파인더coffeefinder제주시청',
#  '양가형제',
#  'Seoul, South Korea',
#  '이익새양과점',
#  '제주도 세화해변',
#  'Harmduck Beach in Jeju Island',
#  '안녕협재씨',
#  '스윗슬로cafe',
#  '제주도 해안도로',
#  '하례정원',
#  '제주도 서귀포',
#  '쇠소깍',
#  '애월늘',
#  'Guzasien -구좌지앵',
#  '제주 한라산 영실코스',
#  '혜화동버거',
#  'Jejudo',
#  '제주 산굼부리',
#  '대평리',
#  '금능해변',
#  '다랑쉬오름',
#  '보름우스테이',
#  '법환동',
#  '천지연폭포 (Cheonjiyeon Waterfall)',
#  '로얄',
#  '선녀와나무꾼',
#  'Hamdeok Jeju',
#  '제주 남원리',
#  '인생밥집',
#  '서귀포시 성산읍',
#  '아름다운 제주도',
#  '유동커피',
#  '구좌읍 평대리',
#  '용연구름다리',
#  '이중섭 거리',
#  '카페루핀',
#  '성산갯마을식당',
#  'Osulloc Tea Museum',
#  '제주시 아라동',
#  '어조횟집',
#  '짱구분식',
#  '김영갑갤러리 두모악',
#  '앤트러사이트 제주 한림점',
#  '평대우유차',
#  '제주 서귀포 그릴 데미그라스',
#  '서울맛집',
#  'Meal Table Garden',
#  'Vadada 바다다',
#  '이런날엔',
#  '신설오름',
#  '하얏트 리젠시 제주ㅣHyatt Regency Jeju',
#  '쌀다방',
#  '제주 윗세오름',
#  '다미진횟집',
#  '남원읍 신례리',
#  'Teddy Bear Museum - 제주 테디베어뮤지엄',
#  '가시식당',
#  '이호테우해변',
#  '외쿡식당',
#  '문치비',
#  '훈이네고사리육개장',
#  'Hotel Alfonso XIII, a Luxury Collection Hotel, Seville',
#  '탐나버거',
#  '김녕회관',
#  '보엠 - Bohème',
#  '말젯문',
#  '우도',
#  '박물관이살아있다',
#  '군산오름',
#  '성산일출봉',
#  '카페주비 - JUBI',
#  '그러므로part.2',
#  '토스카나호텔',
#  '로맨틱무브',
#  '광안리 해수욕장 - 廣安里海水浴場 GwangalliBeach, Busan, South Korea',
#  '한림칼국수',
#  '평대리 해변',
#  '핏제리아마노',
#  'Ulsan, South Korea',
#  '모슬 포항',
#  '제주도 한경면',
#  '서귀포흑돈',
#  '켄싱턴 제주호텔',
#  '순옥이네명가',
#  '지오반니',
#  '영육일삼',
#  '함덕호랑이',
#  '센트로',
#  'CAFE E.P.L',
#  '애월해안가',
#  '모슬포항 만선식당',
#  '신창풍차해안도로',
#  'Hotel NANTA 호텔 난타',
#  '테지움 제주',
#  'Jeju_Gimnyeong_Maze_Park',
#  '동굴카페 다희연(Cafe Daheeyeon in the Cave)',
#  '목장카페 드르쿰다',
#  '삼미흑돼지',
#  '제주마방목지',
#  '그계절',
#  '판포포구',
#  '중문 덤장',
#  'Daegu, South Korea',
#  'Longlive',
#  '문쏘',
#  '우동가게',
#  '하도리1091',
#  '성읍민속마을',
#  '대정읍',
#  '제주 도두동',
#  '다다의작은공간',
#  '블리스찬',
#  'Salon de Lavant',
#  '황우지해안',
#  '새연교횟집',
#  '한림항',
#  '오롯',
#  '이정의댁',
#  '부두식당',
#  '붉은못허브팜 Cafe Redpond 애월본점',
#  '제주돌마을공원',
#  '2월22일 브런치카페',
#  '천제연폭포',
#  '선흘리 동백동산',
#  'Cafe148',
#  '뉴저지카페',
#  '쿠오모제주',
#  '백약이 오름',
#  '제주 휴애리',
#  '비브레이브 커피 로스터즈',
#  '가시아방',
#  '제주시 동문시장',
#  '꽃기린 카페',
#  '판포리',
#  '족황상제',
#  '그초록',
#  '만세국수삼성혈점',
#  '컴피하우스',
#  '복자씨연탄구이',
#  '제주 조류공원 화조원',
#  '윗세오름(해발 1700M)',
#  '이음',
#  '용두암',
#  '아쿠아 플라넷 제주 (Aqua Planet JEJU)',
#  '소보리당로 222',
#  '제주 구좌읍 세화리',
#  '스튜디오 쿠나',
#  '빨간머리몽게스트하우스',
#  '남원읍 위미리 귤밭',
#  '제주허브동산',
#  '슬슬슬로우',
#  '아부오름',
#  '볼스카페',
#  '테쉬폰',
#  '올레7코스',
#  '済州島 - チェジュ島',
#  '상호네숯불구이',
#  '테디베어뮤지엄',
#  '서귀포 까망돼지',
#  'Hamdoek Beach, Jeju Island',
#  '호텔 몽듀',
#  '제주도 천지연 폭포',
#  '모뉴에트',
#  'JEJU앨리스',
#  'Ecoland Theme Park Forest Train黃花小火車',
#  '라온더마파크',
#  '자매국수 노형점',
#  '제주 이호해수욕장',
#  '그리울땐 제주',
#  '천지연폭포',
#  '천왕사 (天王寺)',
#  '초밥충전',
#  '연정식당',
#  'Oedolgae Jeju',
#  '해왓',
#  '제주서커스월드공연장',
#  '로컬크랩',
#  '제주시외버스터미널',
#  '봄날',
#  '대우정',
#  '갈중이',
#  '밥의정석',
#  '바닐라파레트',
#  '한동올레펜션',
#  '중문색달해변 (Jungmun Saekdal Beach)',
#  '카페두가시',
#  '빨간모자마법사',
#  '따라비오름',
#  '아도록',
#  '한담해안산책로',
#  'Namwon Seogwipo Jeju,South korea',
#  '칠돈가',
#  '사라봉근처',
#  '함덕해변',
#  '난드르바당',
#  'Antoinette',
#  'South Korea',
#  '형제국수',
#  '애월더선셋',
#  '제스토리, 바이제주, 제주감성소품',
#  'Hyatt Regency, Jeju Island',
#  '제주도 전주횟집',
#  '제주김만복',
#  '토끼썸',
#  '삼공주회센터',
#  '숨비아일랜드',
#  '빌라드아토',
#  'Uncommon Table',
#  '모메든식당',
#  '이게밥도둑',
#  '쉐프부부',
#  'Bongcheon-dong',
#  '지금여기',
#  '홍키호테',
#  '타쿠마 - Takuma',
#  '카페모리&베이커스트리트',
#  '헤이브라더',
#  '올레안뜰',
#  '젠하이드어웨이',
#  '소우',
#  'Gwakji Beaches',
#  '비스트로낭',
#  'Salon De 소자38',
#  '수제홍과일모찌하귀점',
#  '충남 대천 해수욕장 에서',
#  'Jamae Guksu',
#  '도라지식당',
#  '호박다방',
#  '중문 단지 삼원정',
#  '마모루',
#  '라비에 와인비스트로',
#  '카페바띠',
#  '리틀이태리 비스트로',
#  '제주엠리조트',
#  '섶섬해녀할망카페',
#  '풍미독서',
#  '털보네고양이',
#  '가드망제',
#  '마구로쇼쿠도',
#  '쿠쿠아림',
#  '바굥식당',
#  '어라운드 폴리 Around Follie',
#  '시루애월 소길점',
#  '제주시동문시장',
#  '바람코지 게스트하우스&카페',
#  '삼다버거',
#  '마포식당',
#  '한모살식당',
#  '어반가라지',
#  '홍대개미제주',
#  '카페송키',
#  '미미본가',
#  '바당지기식당',
#  '서귀포 기억나는집',
#  '버드나무집',
#  'Coco Mama',
#  '소금바치 순이네',
#  '아산 음봉',
#  '하노이안브라더스',
#  '군산 정상',
#  '반딧불 한담',
#  '과일애',
#  '제주 사랑분식',
#  '제주한면가 濟州韓麵家',
#  '못생김',
#  '중문국수나라',
#  'Cafe멘도롱',
#  '드렁큰디제이',
#  '협재칼국수',
#  '시민갈비',
#  '우진해장국',
#  '로드129',
#  '자갈자갈',
#  '팀버 커피 제주',
#  '제주시',
#  '공천포 식당',
#  '해바라기 분식',
#  '해비치호텔&리조트 - Haevichi hotel & resort',
#  '벵디',
#  'Cafe카페인',
#  '봉개동',
#  '베이크샵스니프 bakeshop sniff',
#  '쭈니창고',
#  '장복호',
#  '모이세해장국',
#  '제주인의밥상',
#  '하례리 망장포구',
#  '제주시 조천읍 와선로 206',
#  '오조해녀의집',
#  '쉼표',
#  '독개물항',
#  'Mansion37.5',
#  '월정곰닭',
#  '포팩토리',
#  '탑동마차',
#  '1342틈',
#  '백리향백반',
#  '푸릇프릍',
#  '북촌플레이스',
#  '마레벤또',
#  'U-do Bong( 우도봉)',
#  "동광 pâtisserie '東光'",
#  '오메오메동문시장점',
#  '도토리키친',
#  '지붕위제주바다',
#  '연화키친',
#  '제주시농협하나로마트',
#  '돈테일러익스프레',
#  "서귀동 298-5 '세계의 가정식'",
#  '훈남횟집',
#  '제주시청',
#  '702키친',
#  '바라크라',
#  '제주도청',
#  'Bonte museum',
#  '제주 팜스빌리지',
#  '김녕장',
#  '서귀포 워터월드',
#  '오설록',
#  '상효원 수목원',
#  '제주워터월드/감귤노천탕',
#  '애월해안도로',
#  '투썸플레이스 제주애월한담점',
#  '유민 아르누보 콜렉션',
#  '몽키비치',
#  '안녕, 육지사람',
#  '제주롯데시네마',
#  'Soror',
#  '신창해안도로',
#  '다이브스테이',
#  '저녁정원',
#  '금악리 제주힐링리조트',
#  '고근산정상',
#  '효돈마을',
#  '한화아쿠아넷',
#  'Volskafé',
#  'Maxim 모카다방',
#  '서건도',
#  '외돌개',
#  '성산일출봉 코앞 쉼터',
#  'Seosan',
#  '에코그린리조트',
#  '구엄리 돌염전',
#  'Ramada Plaza Jeju',
#  '골목카페 옥수',
#  '해물뚝배기전문 재암식당',
#  '블루마린하우스',
#  '고기마씸',
#  '협재술시',
#  'Saeyeon Bridge, Jeju Island',
#  '테라로사-이사랑',
#  '구좌상회',
#  '깡촌흑돼지',
#  '개똥이네 동물원',
#  '제주도 용두암',
#  '중문 마린파크 퍼시픽랜드',
#  'Oslob, Cebu',
#  '十五夜 siboya 십오야',
#  '폴레폴레게스트하우스 -Polepole Guesthouse in Jeju',
#  'Ocean Suites Jeju Hotel',
#  '전주콩나물국밥',
#  '박물관은 살아있다 제주 중문',
#  '명진전복',
#  '헤이미쉬제주_제주독채펜션',
#  '하도해변',
#  '송당리 풍림다방',
#  '중문관광단지 (Jungmun Tourism Complex)',
#  '호연스테이',
#  '한성식당',
#  '제주항공',
#  '포근한우리집',
#  '스물다섯',
#  'Cafe가호',
#  '카페소금',
#  '비양도 해녀촌',
#  '네이처트레일',
#  '반디앤로제이',
#  '카페라능',
#  '대구국제공항',
#  '이중섭 미술관',
#  '오운커피',
#  '타시텔레',
#  '사락',
#  '모던하우스 제주점',
#  '카페하도섬/엠스테이펜션',
#  '돈사돈중문점',
#  '썬앤문리조트',
#  '73st',
#  '서귀포 칼호텔 (KAL Hotel Seogwipo)',
#  '성산포',
#  '제주카페 스르륵',
#  '나주혁신도시',
#  'playce',
#  '하늘고래',
#  '신천목장',
#  '섭지코지 (Seopjikoji)',
#  '제주좋은날',
#  '호끌락80번지',
#  '벵디1967',
#  '우도 비양도',
#  '비싸이드엠,beside-M',
#  '제주초가집 곱들락',
#  '헤밍웨이 하우스',
#  '조천읍 북촌리',
#  '인공위성 제주',
#  '제주도립미술관',
#  '협재',
#  '제주인에이에이',
#  '제주도 표선',
#  '네이처캔바스',
#  '머스태쉬커피/머스태쉬하우스',
#  'Paz',
#  '마담제 게스트하우스',
#  '단디501',
#  '제주 성산읍',
#  'Kairos jeju',
#  '방주교회',
#  '카이로스 제주',
#  'TheFirst70 Hotel',
#  'ECOLAND theme park',
#  '켄싱턴리조트 서귀포',
#  '국수의 전설',
#  '시리우스 호텔',
#  '나도섬이다',
#  'Howard Johnson Jeju Yeondong Hotel - 하워드존슨 제주 연동 호텔',
#  '제주김만복본점',
#  '이호테우 목마등대',
#  'BUTTON STAY 단추스테이 게스트하우스',
#  '고불락 식당',
#  '제주조천스위스마을',
#  '수망일기',
#  '올레 6코스 (Olle Route 6)',
#  '사우스바운더 Southbounder Brewery',
#  '차귀도',
#  '까망고띠',
#  '함덕 다래향',
#  '돈사촌',
#  '꽃이다카페',
#  '세종시',
#  '잔향',
#  '시루애월카페',
#  '꽃밥',
#  'Cultured',
#  '빌리엔젤 제주노형점',
#  '공업탑',
#  '고로케야',
#  'Shilla Stay',
#  '내콩가',
#  '스테이굿무드',
#  '해심가든',
#  '수카사',
#  '제주 월령선인장 군락지',
#  'Bronx, New York',
#  'The Retrieve',
#  '제주 이호테우 해변',
#  '여름문구사',
#  '객의하우스',
#  '섭지코지 등대',
#  '더아트스테이호텔-The Artstay Hotel',
#  'MBC',
#  '오렌지블루스',
#  '제주도 휘닉스아일랜드',
#  '지붕 위 제주바다',
#  'Cafe delmundo',
#  '금능반지하',
#  '달사막',
#  '절물 자연 휴양림',
#  'Tj Guesthouse',
#  'Gimpo International Airport - 金浦国际机场 - 김포공항',
#  '카페어떤오후',
#  '협재 수우동',
#  'M-STAY / 엠스테이',
#  'La Tortuga',
#  '비긴어게인펜션',
#  '바램목장&카페',
#  '산방굴사 (Sanbanggulsa Temple 山房窟寺)',
#  '종달스토리 게스트하우스',
#  '색달식당',
#  '책다방',
#  '동문시장',
#  '표선리',
#  '자구리 카페 몬들락 Cafe Mondeulrak',
#  '사라오름 산정호수',
#  '제주도 고근산',
#  '제주마로 펜션',
#  '책방무사',
#  '항파두리 항몽유적지',
#  '블루라군다이브-bluelagoondive',
#  'Hwasun',
#  '베케',
#  '제주도 하늘 위',
#  '제주맑음',
#  '스테이 비갠오후',
#  '제주 반디앤로제이 펜션 & 플라워브런치카페',
#  '종달리 해변',
#  '제주돌문화공원',
#  '피규어뮤지엄제주',
#  '한동리 화수목',
#  'Enough, 이너프',
#  '함덕 Fishya',
#  '표선 해비치해수욕장',
#  '게으른날',
#  '에코랜드테마파크',
#  '원더먼트제주',
#  '시월의리브라',
#  '카페닐스',
#  '평화통일불사리탑사',
#  '담앤루리조트',
#  '한라산 정상 해발 1,950m',
#  '우리두리게스트하우스',
#  '목수금토일',
#  'Gimpo International Airport Station',
#  '제주국제공항 활주로 (Jeju Airport Runway)',
#  '정동진',
#  '수제홍과일모찌',
#  '돌마을공원',
#  '서머셋 제주신화월드',
#  '아름다운제주여행',
#  '노리매',
#  '탑동해변공연장',
#  '산방산',
#  '제주세계자연유산센터',
#  'Suweolbong Trekking',
#  '제주 나인브릿지 CC',
#  '제주도 부영리조트',
#  '화순금모래해변',
#  '연북정',
#  '제주신라면세점',
#  '니모메빈티지라운지',
#  '나인브릿지',
#  '월정스캔들',
#  '노형 수목원가는길',
#  '저지예술인마을',
#  '기원뚝배기',
#  '산방산 (Sanbangsan)',
#  'Ocean Suite Jeju Hotel (오션스위츠제주호텔)',
#  '제주오리엔탈호텔',
#  '제주웰컴센터',
#  '새별오름 정상',
#  '돼지촌',
#  '에코랜드 라벤다앤그린티로즈가든역',
#  'Jeju National University',
#  'Jeju Island, South Korea - 제주도',
#  '웃뜨르',
#  '대굴대굴굴구이',
#  '용담해안도로',
#  '정방폭포가 보이는 암벽위',
#  '카페2472',
#  '쪼끌락 cafe',
#  '동한두기',
#  '더스파',
#  '제주중앙로상점가',
#  '환상숲곶자왈공원',
#  '휘슬락호텔',
#  '올레길 5코스',
#  '닭머르',
#  '미나마라',
#  '성산수구레국밥',
#  '탑동광장편의점',
#  '제주 생각하는 정원',
#  'Dammann Frères_다만프레르_제주신화점',
#  '제주대학교 교양강의동',
#  '돌담너머바다',
#  '강식당',
#  '성수족발',
#  '덕수하루펜션',
#  '바다의집',
#  '카페 호꼼',
#  '스모크하우스인구억',
#  '전라북도 군산 경암동 철길마을',
#  '속초 아바이마을',
#  '한림 칠돈가',
#  '제주집',
#  'Jungle book by Alice',
#  '문섬',
#  '부산 맛집 여기',
#  'LOTTE City Hotel Jeju 롯데시티호텔제주',
#  '제주몬트락',
#  '청사포 수민이네',
#  '옥계휴게소',
#  '스타양곱창',
#  '선화동106-1',
#  '제주 운정이네',
#  '필립헤어',
#  'Ulsan, Korea',
#  '제주도 한림',
#  '착한스시',
#  '협제 혜변',
#  '보목',
#  '제주아리아',
#  '한림공원 Hallimpark',
#  'Saturdayisland',
#  '서귀포 이마트',
#  'Cafe Koomda',
#  'Seoul, Korea',
#  '한라생태숲',
#  '제주아트리움"비밀의그림자"공연',
#  '관덕정',
#  '알뜨르프로젝트2018',
#  '엉또폭포',
#  '유리의성과마법의숲',
#  '동문로터리',
#  '제주여행 가야밀면',
#  '접대 - 저번에 우리가 만났던 그때',
#  '광안리 앙상블',
#  '윈드스톤',
#  'Sensō-ji',
#  '용두암해변',
#  '날것',
#  '큰엉전망대쉼터',
#  'Cafe기억해',
#  '사계여행',
#  '스타벅스 제주성산dt점',
#  'Maison GLAD Jeju - 메종글래드 제주',
#  '호텔 아이엠',
#  '제주프레임스파빌',
#  '오샹띠',
#  '서귀포향토오일장',
#  '1158 Cafe',
#  '동박낭',
#  'Marevo Resort / 마레보 리조트',
#  '김녕 앞바다',
#  'Segovia, Spain',
#  '구좌상회작업실',
#  '가시아방국수',
#  '오드랑베이커리',
#  '채점석빵집',
#  '신풍목장',
#  '요요무문',
#  '제주도 하도리',
#  '바보까페',
#  '우도 하고수동해수욕장',
#  '렛츠런팜제주',
#  '제주시도두항',
#  '서귀포 법환포구',
#  'Jeju Starbucks 용담dt',
#  '외도동',
#  '순덕이네해산물장터',
#  '한복입는 선흘집',
#  '돈물국수',
#  '덕인당 소락',
#  '무수천계곡',
#  '제주시 화북동',
#  '제주거울미로 이상한나라의앨리스',
#  'Arc de Triomphe',
#  '피규어 뮤지엄 제주  Figure Museum Jeju',
#  '아날로그감귤밭',
#  '황궁쟁반짜장',
#  'Hallasan',
#  '노형로터리',
#  '금바리',
#  '건축카페 - 섶섬이보이는',
#  '도두항',
#  '서양차관',
#  'Paju',
#  'Shimo-kitazawa Station',
#  '스트라이크볼링센터',
#  '종가전복',
#  '서귀포잠수함',
#  '석부작테마공원',
#  '와흘리',
#  '초콜릿랜드 / Chocolate Land',
#  'Yacht Tour Shangri-La',
#  '정방 폭포',
#  '관음사',
#  '제주비치호텔 함덕',
#  'Sangumburi Crater',
#  '미도리',
#  '서귀포의료원',
#  'Hibi & Kohaku',
#  '호텔위드제주',
#  '산천단',
#  'Shmonga',
#  '쉬리의 언덕',
#  '코코몽 에코랜드',
#  '올레길',
#  '귀덕1리',
#  '보롬왓',
#  '랍스터빈_jeju',
#  '제주하귀휴먼시아',
#  '제주베니스랜드',
#  '고성리',
#  '더본호텔',
#  'Málaga, Spain',
#  '화북1동',
#  '자연뜨락',
#  '비양도',
#  '제주도가는 비행기 안',
#  '제주 천제연폭포',
#  '우도 (Udo / 牛島)',
#  'Teseum',
#  '비자림 (Bija Forest, 榧子林)',
#  '제주함덕 해수욕장',
#  'GD Cafe',
#  '델문도 제주 카페 Cafe Delmoondo',
#  '김녕 성세기 해변',
#  '제주도 더마파크',
#  'Halim jeju korea Selatan',
#  '제주도 귤밭',
#  '제주마라도잠수함',
#  '어부의딸',
#  '스시애월',
#  '꽃돼지연탄구이',
#  '세인트포cc',
#  '여수 앞바다',
#  '무거버거',
#  '유리네 식당',
#  '화산양꼬치2호점',
#  'Myeongjin Abalone',
#  '달달콤콤',
#  'Jaju,south Korea',
#  '규태네 양곱창',
#  'KBS본관',
#  '쇠소깍오메기식당',
#  '배블리컨테이너',
#  '마가리따 은혜씨cafe&Dining pub',
#  'Cafe Ri',
#  '神의 한모(신의 한모)',
#  '카페오길',
#  '풍원 한라산볶음밥',
#  '홍대부부',
#  '모던플레이스 리조트',
#  '성읍칠십리식당',
#  '자구내포구',
#  '남포커피',
#  '크랩잭제주',
#  '마로니에 공원',
#  'Thecoffeebrew-더커피브루',
#  '제주 신재생에너지 홍보관',
#  '한림 바당길',
#  '오마주마카롱',
#  '연동포차',
#  '양대곱',
#  '깐깐한족발',
#  '오는정 김밥',
#  '뽕끄랑',
#  '홍대 깐풍기브라더스',
#  'CAMPHORTREE Hotel & Resort',
#  '날씬흑돼지',
#  '삼보식당',
#  '주점부리',
#  '수월봉',
#  '흑돼지가있는풍경',
#  '물꼬기',
#  '블랙하우스 떡볶이레스토랑',
#  '대우정식당',
#  '청루 봉평 메밀 막국수',
#  '큰돈가',
#  '모니카옛날통닭',
#  '메이즈랜드',
#  '소렉',
#  '토도',
#  '인사리',
#  '제주시 고요남',
#  '해녀엄마의집',
#  '서촌제',
#  '제주 오션스토리',
#  '은실이네 게스트하우스',
#  '면뽑는선생 만두빚는아내',
#  '바다이야기',
#  '칠돈가 본점',
#  '에이그라운드',
#  "Jerry's PUB",
#  '제주칼국수 제주해물탕',
#  '블루밍아일랜드 Blooming Island',
#  '촵촵 - Chwap Chwap',
#  '행원포구',
#  '신흥동 일본식가옥',
#  '8월의크리스마스 초원사진관',
#  '이스트엔드',
#  '제주신화월드 메리어트 리조트관',
#  '키작은삼촌',
#  '엉장매하우스',
#  '고관해물탕, 초량',
#  '브라운스위트 제주',
#  '제주 대명리조트',
#  '제주도맛집',
#  '동탄2에 산다',
#  '청초수물회&섭국 [신관]',
#  '속초 엄지네포장마차',
#  '오라게게스트하우스',
#  '미영이네식당',
#  '내츄럴케이',
#  '제주스럽닭',
#  '바삭돈가스',
#  '새우조나단',
#  '대춘해장국',
#  '금능샌드',
#  'Novotel Ambassador Daegu',
#  '참맛나김밥',
#  '리치망고 협재점',
#  '가배',
#  '떡하니',
#  'Shineville Luxury Resort',
#  '듀블라썸',
#  '카페오드리',
#  '낙지로',
#  '키아스마',
#  '일도전복',
#  '대돈',
#  '광원',
#  '곰막 횟집',
#  '부자식당',
#  '핸드테일러 제주점',
#  '곱을락',
#  '곽지스테이션',
#  '쉬림포크shrimpork',
#  '교래 손 칼국수',
#  '사이카레',
#  '현대백화점 울산점',
#  '테디밸리골프리조트',
#  '제주중문관광단지',
#  '김포 구래동',
#  '성산스쿠버리조트',
#  '카페록록 Loklok',
#  '흑송',
#  '제주시 새우리',
#  '거멍국수',
#  '갈치왕',
#  '청춘게스트하우스',
#  'OLD STUFF 올드스터프 Coffee&bread',
#  '김녕해수욕장 (Gimnyeong Beach)',
#  '도깨비명당',
#  '서촌제 (서울촌놈인제주)',
#  '맛있는 제주',
#  '자매국수 본점',
#  "That's very",
#  '세영수산',
#  '전주도',
#  '팔도수산식당',
#  '사방팔방 외도점',
#  '남원 포구',
#  '나원횟집',
#  '미풍해장국  중앙점',
#  '대기정',
#  '유채꽃사진촬영소',
#  '정관신도시',
#  '몽구네민박',
#  'Gagamel',
#  '경성대 맛집',
#  '자연스러운식당',
#  '바다사랑그리고추억',
#  '제주송정농원',
#  '제주 이자와',
#  '우리집아점',
#  '플레이스엉물',
#  '치저스 제주',
#  '동복해녀촌',
#  '웃뜨르 우리돼지',
#  '한림 뽈살집',
#  '덕승식당',
#  '말미오름 (두산봉)',
#  '효섬마을 초가집',
#  '기쁨이네 감자탕',
#  '부촌식당',
#  '릴리펏 제주점 메종글래드호텔',
#  '담아래',
#  '제주돈아',
#  '제주한라수목원♥',
#  '민경이네 어등포해녀촌',
#  ...]

# %% [markdown]
# ##### 카카오 Open API로 장소 검색
# - 카카오 개발자 사이트에서 애플리케이션 등록
# - 키 생성

# %%
shopName = '제주 크리스마스 박물관'
url = f'https://dapi.kakao.com/v2/local/search/keyword.json?query={shopName.replace(" ", "_")}'

header = { 'Authorization' : 'KakaoAK 본인 키'} # 키는 본인키 사용

places = requests.get(url, headers=header).json()['documents']
places
# Out:
# [{'address_name': '제주특별자치도 서귀포시 안덕면 서광리 456',
#   'category_group_code': 'CT1',
#   'category_group_name': '문화시설',
#   'category_name': '문화,예술 > 문화시설 > 박물관',
#   'distance': '',
#   'id': '495587934',
#   'phone': '010-4602-7976',
#   'place_name': '바이나흐튼 크리스마스박물관',
#   'place_url': 'http://place.map.kakao.com/495587934',
#   'road_address_name': '제주특별자치도 서귀포시 안덕면 평화로 654',
#   'x': '126.32779866033343',
#   'y': '33.29131209935493'},
#  {'address_name': '제주특별자치도 서귀포시 안덕면 서광리 456',
#   'category_group_code': 'PK6',
#   'category_group_name': '주차장',
#   'category_name': '교통,수송 > 교통시설 > 주차장',
#   'distance': '',
#   'id': '1147068025',
#   'phone': '',
#   'place_name': '바이나흐튼 크리스마스박물관 주차장',
#   'place_url': 'http://place.map.kakao.com/1147068025',
#   'road_address_name': '제주특별자치도 서귀포시 안덕면 평화로 654',
#   'x': '126.327797600638',
#   'y': '33.2913102904037'}]

# %%
## 장소 검색 함수 findPlace
def findPlaces(shopName):
    # 1. 검색API 주소변수 
    url = f'https://dapi.kakao.com/v2/local/search/keyword.json?query={shopName}'
    # 2. header 구성
    header = { 'Authorization' : 'KakaoAK 본인 키'} # 키는 본인키 사용
    # 3. API를 웹으로 요청, 결과 return
    places = requests.get(url, headers=header).json()['documents']
    # 4. 필요정보만 추출
    place = places[0]
    realName = place['place_name']
    lat = place['y']    # 위도(latitude)
    lng = place['x']    # 경도(longitude)
    phoneNum = place['phone']
    address = place['address_name']

    return [shopName, realName, phoneNum, address, lat, lng]

# %%
# test
result = findPlaces('제주 공항')    #하루 제한 개수 존재
result
# Out:
# ['제주 공항',
#  '제주국제공항',
#  '1661-2626',
#  '제주특별자치도 제주시 용담2동 2002',
#  '33.5070789578184',
#  '126.492769004244']

# %%
# Locations 리스트를 반복문으로 주소 가져오는 처리
locationResults = []

for loc in tqdm(Locations):
    try:
        data = findPlaces(loc)
        locationResults.append(data)
        time.sleep(0.3)
    except:
        pass
# Out:
# 100%|██████████| 1028/1028 [10:54<00:00,  1.57it/s]

# %%
locationResults
# Out:
# [['Jeju',
#   'R고기 in Jeju',
#   '064-744-6222',
#   '제주특별자치도 제주시 도두일동 2623-4',
#   '33.503587560005954',
#   '126.46542934219148'],
#  ['Seogwipo',
#   '서귀포잠수함',
#   '064-732-6060',
#   '제주특별자치도 서귀포시 서홍동 707-5',
#   '33.2393033784206',
#   '126.558616052674'],
#  ['제주도 크리스마스 박물관',
#   '바이나흐튼 크리스마스박물관',
#   '010-4602-7976',
#   '제주특별자치도 서귀포시 안덕면 서광리 456',
#   '33.29131209935493',
#   '126.32779866033343'],
#  ['할로비치',
#   '할로비치',
#   '',
#   '서울 강남구 신사동 511-7',
#   '37.5182108620338',
#   '127.020825988861'],
#  ['제주에인감귤밭',
#   '제주에인감귤밭',
#   '',
#   '제주특별자치도 서귀포시 호근동 693',
#   '33.25656069063887',
#   '126.5390139270361'],
#  ['Jeju Island',
#   '제주도',
#   '',
#   '제주특별자치도 제주시 오등동 산 182',
#   '33.379777816446165',
#   '126.54587355630036'],
#  ['1100고지',
#   '한라산1100고지',
#   '',
#   '제주특별자치도 서귀포시 색달동 산 1-2',
#   '33.3580781709788',
#   '126.462219691112'],
#  ['월정리해변',
#   '월정리해수욕장',
#   '064-728-3394',
#   '제주특별자치도 제주시 구좌읍 월정리 33-3',
#   '33.556469394054',
#   '126.795805057888'],
#  ['고집돌우럭중문점',
#   '고집돌우럭 중문점',
#   '0507-1408-1540',
#   '제주특별자치도 서귀포시 색달동 2351',
#   '33.2579811121134',
#   '126.416704762779'],
#  ['석부작박물관',
#   '숨도',
#   '064-739-5588',
#   '제주특별자치도 서귀포시 호근동 569-2',
#   '33.25045551460648',
#   '126.53652102219156'],
#  ['제주도 애월읍',
#   '올레길 16코스(고내-광령 올레)',
#   '',
#   '제주특별자치도 제주시 애월읍 수산리 1831-2',
#   '33.46879638867176',
#   '126.38736766269528'],
#  ['알뜨르 비행장',
#   '알뜨르비행장',
#   '',
#   '제주특별자치도 서귀포시 대정읍 상모리 1670',
#   '33.2047161778831',
#   '126.271527320164'],
#  ['카멜리아 힐',
#   '카멜리아힐',
#   '064-800-6296',
#   '제주특별자치도 서귀포시 안덕면 상창리 271',
#   '33.290336568694215',
#   '126.36819010853146'],
#  ['제주레포츠랜드',
#   '제주도 카트 제주레포츠랜드',
#   '064-784-8800',
#   '제주특별자치도 제주시 조천읍 와흘리 870',
#   '33.48206819907232',
#   '126.6387551242765'],
#  ['밥깡패',
#   '유진푸드',
#   '',
#   '대전 서구 둔산동 1380-1',
#   '36.3562604784963',
#   '127.387893413315'],
#  ['제주 함덕 서우봉 해변',
#   '함덕해수욕장',
#   '064-728-3989',
#   '제주특별자치도 제주시 조천읍 함덕리 1004-10',
#   '33.5430615661113',
#   '126.669238934013'],
#  ['위미동백나무군락지',
#   '위미동백나무군락',
#   '',
#   '제주특별자치도 서귀포시 남원읍 위미리 903-1',
#   '33.2729387205764',
#   '126.67473058287'],
#  ['제주신화월드 Jeju Shinhwa World',
#   '제주신화월드 서머셋',
#   '1670-8800',
#   '제주특별자치도 서귀포시 안덕면 서광리 산 24-15',
#   '33.30282676121975',
#   '126.31725350392803'],
#  ['Woljeongri Beach',
#   '월정리해수욕장',
#   '064-728-3394',
#   '제주특별자치도 제주시 구좌읍 월정리 33-3',
#   '33.556469394054',
#   '126.795805057888'],
#  ['협재해변 Beach',
#   '협재해수욕장',
#   '064-728-3981',
#   '제주특별자치도 제주시 한림읍 협재리 2447',
#   '33.3938660776221',
#   '126.239157539085'],
#  ['연동 바오젠 거리',
#   '누웨마루거리',
#   '',
#   '제주특별자치도 제주시 연동 273',
#   '33.48601183492031',
#   '126.490657044139'],
#  ['고래배꼽',
#   '고래배꼽',
#   '',
#   '광주 서구 풍암동 1083-2',
#   '35.1226084499662',
#   '126.882411554095'],
#  ['새별오름',
#   '새별오름',
#   '064-728-2752',
#   '제주특별자치도 제주시 애월읍 봉성리 산 59-8',
#   '33.366277591139294',
#   '126.3577306657398'],
#  ['용머리해안',
#   '용머리해안',
#   '064-760-6321',
#   '제주특별자치도 서귀포시 안덕면 사계리',
#   '33.2316567556941',
#   '126.314736627312'],
#  ['용눈이오름',
#   '용눈이오름',
#   '',
#   '제주특별자치도 제주시 구좌읍 종달리 산 28',
#   '33.45988023593872',
#   '126.83268298189506'],
#  ['캔디원',
#   '캔디원',
#   '064-784-5260',
#   '제주특별자치도 제주시 조천읍 선흘리 1776',
#   '33.4712938141156',
#   '126.707750215953'],
#  ['사려니숲길',
#   '사려니숲길',
#   '064-900-8800',
#   '제주특별자치도 제주시 조천읍 교래리 산 137-1',
#   '33.422032834994496',
#   '126.62649730394567'],
#  ['하이엔드 제주',
#   '하이엔드주방가구',
#   '010-2940-2600',
#   '제주특별자치도 제주시 연동 304-26',
#   '33.4843001081752',
#   '126.496712850906'],
#  ['제주빅볼랜드',
#   '제주빅볼랜드',
#   '1588-6418',
#   '제주특별자치도 제주시 구좌읍 송당리 산 164-4',
#   '33.4430888345241',
#   '126.775697592995'],
#  ['서귀포 느영나영 게스트하우스',
#   '느영나영게스트하우스',
#   '064-764-5002',
#   '제주특별자치도 서귀포시 남원읍 신흥리 168-8',
#   '33.3007496994456',
#   '126.766699879038'],
#  ['휴애리 자연생활공원',
#   '휴애리자연생활공원',
#   '064-732-2114',
#   '제주특별자치도 서귀포시 남원읍 신례리 2081',
#   '33.309410458656',
#   '126.635409752107'],
#  ['옹포리',
#   '해안도로입구 옹포귀덕',
#   '',
#   '제주특별자치도 제주시 한림읍 옹포리 350',
#   '33.4071142226903',
#   '126.254341199384'],
#  ['삼무공원',
#   '삼무공원',
#   '',
#   '제주특별자치도 제주시 연동 270-3',
#   '33.4917504047058',
#   '126.49151979485'],
#  ['마마뜰',
#   '마마뜰',
#   '',
#   '제주특별자치도 서귀포시 안덕면 동광리 1393-8',
#   '33.3101922253042',
#   '126.333571516211'],
#  ['제주어린왕자게스트하우스',
#   '어린왕자게스트하우스',
#   '010-3393-3132',
#   '제주특별자치도 서귀포시 대정읍 안성리 1701-1',
#   '33.253506631106',
#   '126.281529623422'],
#  ['위미동백나무군락',
#   '위미동백나무군락',
#   '',
#   '제주특별자치도 서귀포시 남원읍 위미리 903-1',
#   '33.2729387205764',
#   '126.67473058287'],
#  ['제주커피박물관 Baum',
#   '제주커피박물관 바움',
#   '064-784-2255',
#   '제주특별자치도 서귀포시 성산읍 고성리 2040-1',
#   '33.4399616687767',
#   '126.89923823378979'],
#  ['Jeju Aewol',
#   '노티드 제주',
#   '070-4415-9377',
#   '제주특별자치도 제주시 애월읍 애월리 2527-3',
#   '33.46327184686136',
#   '126.30972281394814'],
#  ['한라산',
#   '한라산국립공원',
#   '064-713-9950',
#   '제주특별자치도 제주시 오등동 산 182',
#   '33.3766655632143',
#   '126.54222094512'],
#  ['광치기해변',
#   '광치기해변',
#   '',
#   '제주특별자치도 서귀포시 성산읍 고성리 224-33',
#   '33.45231690975651',
#   '126.92389656873524'],
#  ['서우봉',
#   '서우봉',
#   '',
#   '제주특별자치도 제주시 조천읍 함덕리 169-3',
#   '33.54584155166335',
#   '126.67758589138624'],
#  ['제주해남',
#   '제주세호해장국 해남점',
#   '061-532-7401',
#   '전남 해남군 해남읍 해리 349',
#   '34.5685947113919',
#   '126.606468489878'],
#  ['카페한라산',
#   '카페한라산',
#   '',
#   '제주특별자치도 제주시 구좌읍 하도리 3200-12',
#   '33.52478250671836',
#   '126.86302545302301'],
#  ['성이시돌목장',
#   '성이시돌목장',
#   '',
#   '제주특별자치도 제주시 한림읍 금악리 142',
#   '33.3477698762559',
#   '126.327321076199'],
#  ['제주 송악산',
#   '송악산',
#   '',
#   '제주특별자치도 서귀포시 대정읍 상모리 산 2',
#   '33.19908293934712',
#   '126.28979142753593'],
#  ['옹포별장가든',
#   '옹포별장가든',
#   '064-796-3146',
#   '제주특별자치도 제주시 한림읍 옹포리 314-2',
#   '33.40498819737068',
#   '126.25793681747341'],
#  ['곽지해수욕장',
#   '곽지해수욕장',
#   '064-728-3985',
#   '제주특별자치도 제주시 애월읍 곽지리 1565',
#   '33.45064040259736',
#   '126.30467759583657'],
#  ['카페브리프',
#   '브리프애월',
#   '064-711-5507',
#   '제주특별자치도 제주시 애월읍 고성리 443',
#   '33.45833920017301',
#   '126.4156409327181'],
#  ['아줄레주',
#   '아줄레주',
#   '0507-1411-4052',
#   '제주특별자치도 서귀포시 성산읍 신풍리 627',
#   '33.366831430170805',
#   '126.83929446652259'],
#  ['에코랜드',
#   '에코랜드테마파크',
#   '064-802-8000',
#   '제주특별자치도 제주시 조천읍 교래리 385-1',
#   '33.4483387252476',
#   '126.670278657345'],
#  ['산굼부리',
#   '산굼부리',
#   '064-783-9900',
#   '제주특별자치도 제주시 조천읍 교래리 166-2',
#   '33.4325740941816',
#   '126.69383199842952'],
#  ['Terarosa - 테라로사',
#   '테라로사 서종점',
#   '1668-2764',
#   '경기 양평군 서종면 문호리 623',
#   '37.624698025453625',
#   '127.35528536911004'],
#  ['세화해수욕장',
#   '세화해변',
#   '064-728-7752',
#   '제주특별자치도 제주시 구좌읍 세화리 1-1',
#   '33.5251436596119',
#   '126.86025618946'],
#  ['디저트쌀롱 톨',
#   '톨쌀롱',
#   '010-5333-8330',
#   '서울 마포구 연남동 493-16',
#   '37.56135665944675',
#   '126.91948212087884'],
#  ['번개과학체험관',
#   '번개과학체험관 전기차충전소',
#   '1899-2100',
#   '제주특별자치도 서귀포시 토평동 1799',
#   '33.2895232728845',
#   '126.5886131451568'],
#  ['Hidden Cliff / 히든 클리프',
#   '히든클리프호텔&네이쳐',
#   '064-752-7777',
#   '제주특별자치도 서귀포시 상예동 625',
#   '33.2547764885257',
#   '126.402595131766'],
#  ['오전열한시',
#   '오전열한시',
#   '070-8813-5576',
#   '제주특별자치도 서귀포시 상예동 1765-1',
#   '33.26675834476253',
#   '126.39425795855624'],
#  ['하도핑크',
#   '하도핑크',
#   '070-8801-5650',
#   '제주특별자치도 제주시 구좌읍 하도리 1624-9',
#   '33.52236365235448',
#   '126.88342136348828'],
#  ['오후새우시',
#   '오후새우시',
#   '010-8662-0349',
#   '제주특별자치도 서귀포시 중문동 2119-3',
#   '33.2515892389543',
#   '126.424190172164'],
#  ['르페도라펜션',
#   '르페도라펜션',
#   '064-732-7002',
#   '제주특별자치도 서귀포시 남원읍 신례리 994',
#   '33.289609743020414',
#   '126.62927939083806'],
#  ['제주 협재 해수욕장',
#   '협재해수욕장',
#   '064-728-3981',
#   '제주특별자치도 제주시 한림읍 협재리 2447',
#   '33.3938660776221',
#   '126.239157539085'],
#  ['소세지가게',
#   '맥주가게',
#   '02-2068-4490',
#   '서울 영등포구 당산동6가 313-1',
#   '37.5354192656822',
#   '126.902300957892'],
#  ['면차롱',
#   '면차롱',
#   '064-796-7832',
#   '제주특별자치도 제주시 한림읍 협재리 1898',
#   '33.3962665795809',
#   '126.243659578692'],
#  ['제주신라호텔',
#   '제주신라호텔',
#   '064-735-5114',
#   '제주특별자치도 서귀포시 색달동 3039-3',
#   '33.24743087763671',
#   '126.40804141124566'],
#  ['친봉산장',
#   '친봉산장',
#   '',
#   '제주특별자치도 서귀포시 상효동 1314-2',
#   '33.2911373041463',
#   '126.596072341382'],
#  ['오설록티뮤지엄',
#   '오설록 티뮤지엄',
#   '064-794-5312',
#   '제주특별자치도 서귀포시 안덕면 서광리 1235-1',
#   '33.30591328662081',
#   '126.28948929546861'],
#  ['주상절리대',
#   '중문대포주상절리대',
#   '064-738-1521',
#   '제주특별자치도 서귀포시 중문동 2768-1',
#   '33.23799399299591',
#   '126.42601744245376'],
#  ['로타리과자점',
#   '파리바게뜨 혜화로타리점',
#   '02-764-0011',
#   '서울 종로구 혜화동 126-4',
#   '37.58526678474034',
#   '127.00073592017254'],
#  ['르토아베이스먼트',
#   '르토아베이스먼트',
#   '070-4408-5525',
#   '제주특별자치도 제주시 구좌읍 평대리 2005',
#   '33.532984763900366',
#   '126.8442963119275'],
#  ['비자림',
#   '비자림',
#   '064-710-7912',
#   '제주특별자치도 제주시 구좌읍 평대리 3161-1',
#   '33.4904083697986',
#   '126.80998754971'],
#  ['노라바',
#   '노라바',
#   '064-772-1900',
#   '제주특별자치도 제주시 애월읍 구엄리 1287-1',
#   '33.4827924545002',
#   '126.376305449139'],
#  ['제주동문재래시장',
#   '제주동문시장',
#   '',
#   '제주특별자치도 제주시 일도일동 1148-2',
#   '33.51278396493313',
#   '126.52830338722843'],
#  ['우아당',
#   '가든오브우아당',
#   '064-739-4860',
#   '제주특별자치도 서귀포시 법환동 134',
#   '33.2414045515247',
#   '126.518377640052'],
#  ['우드노트',
#   '우드노트',
#   '0507-1330-5352',
#   '서울 송파구 풍납동 299-1',
#   '37.5345598007673',
#   '127.111818009785'],
#  ['LOTTE Hotel Jeju 롯데호텔제주',
#   '롯데시티호텔 제주',
#   '064-730-1000',
#   '제주특별자치도 제주시 연동 2324-6',
#   '33.4906945837847',
#   '126.486477218467'],
#  ['춘심이네 본점',
#   '춘심이네 본점',
#   '0507-1420-4018',
#   '제주특별자치도 서귀포시 안덕면 창천리 160-4',
#   '33.2644856335509',
#   '126.37053351760031'],
#  ['서귀포 매일올레시장',
#   '서귀포매일올레시장',
#   '064-762-1949',
#   '제주특별자치도 서귀포시 서귀동 277-1',
#   '33.25015006260236',
#   '126.56323157639459'],
#  ['녹근로33',
#   '녹근로33',
#   '064-799-3340',
#   '제주특별자치도 제주시 애월읍 봉성리 3228-2',
#   '33.415729677720606',
#   '126.31433507124518'],
#  ['명월국민학교',
#   '명월국민학교',
#   '070-8803-1955',
#   '제주특별자치도 제주시 한림읍 명월리 1734',
#   '33.3887377492719',
#   '126.264871685447'],
#  ['남원큰엉해안경승지',
#   '남원큰엉해변',
#   '',
#   '제주특별자치도 서귀포시 남원읍 남원리 2379-3',
#   '33.2733501754907',
#   '126.703710044663'],
#  ['플레이스 캠프 제주',
#   '플레이스캠프제주',
#   '064-766-3000',
#   '제주특별자치도 서귀포시 성산읍 고성리 297-1',
#   '33.44982752239807',
#   '126.91817254328247'],
#  ['만월당',
#   '만월당',
#   '064-784-5911',
#   '제주특별자치도 제주시 구좌읍 월정리 591-1',
#   '33.5561833763201',
#   '126.792962824224'],
#  ['제주도',
#   '제주도',
#   '',
#   '제주특별자치도 제주시 오등동 산 182',
#   '33.379777816446165',
#   '126.54587355630036'],
#  ['수목원테마파크',
#   '배다골테마파크 식물원',
#   '',
#   '경기 고양시 덕양구 화정동 8-1',
#   '37.6306413985241',
#   '126.846971579726'],
#  ['Hidden Cliff Hotel & Nature',
#   '히든클리프호텔&네이쳐',
#   '064-752-7777',
#   '제주특별자치도 서귀포시 상예동 625',
#   '33.2547764885257',
#   '126.402595131766'],
#  ['지금이순간카페',
#   '지금이순간',
#   '',
#   '경기 김포시 하성면 전류리 63',
#   '37.6977868150702',
#   '126.662095611501'],
#  ['제주꿈꾸는고래',
#   '꿈꾸는고래',
#   '064-787-4597',
#   '제주특별자치도 서귀포시 표선면 세화리 128-5',
#   '33.3077566755429',
#   '126.808038421406'],
#  ['Jungmun Beach',
#   '중문색달해수욕장',
#   '064-738-4843',
#   '제주특별자치도 서귀포시 색달동 3039',
#   '33.2450381505136',
#   '126.411498674889'],
#  ['Jeju International Airport',
#   '제주국제공항',
#   '1661-2626',
#   '제주특별자치도 제주시 용담2동 2002',
#   '33.5070789578184',
#   '126.492769004244'],
#  ['하늘아래 게스트하우스',
#   '하늘아래 게스트하우스',
#   '010-2408-5602',
#   '제주특별자치도 서귀포시 표선면 세화리 1424-3',
#   '33.315123515115',
#   '126.800922820428'],
#  ['서귀포항',
#   '서귀포항',
#   '',
#   '제주특별자치도 서귀포시 서귀동',
#   '33.2367989759913',
#   '126.566400846169'],
#  ['명랑스낵',
#   '명랑스낵',
#   '070-4245-4548',
#   '제주특별자치도 제주시 한림읍 한림리 1479-4',
#   '33.4091714181718',
#   '126.258817154541'],
#  ['제주여행',
#   '제주여행',
#   '031-531-6900',
#   '경기 포천시 영북면 산정리 529',
#   '38.07053612435701',
#   '127.3041879999479'],
#  ['붉은제주',
#   '붉은오름자연휴양림',
#   '064-782-9171',
#   '제주특별자치도 서귀포시 표선면 가시리 산 158',
#   '33.4014900759295',
#   '126.675361753765'],
#  ['아뜰리에안',
#   '아뜰리에안',
#   '064-739-8100',
#   '제주특별자치도 서귀포시 법환동 1541',
#   '33.23151206961391',
#   '126.50601257107456'],
#  ['푸른섬 제주도',
#   '푸른섬게스트하우스',
#   '010-9728-2160',
#   '제주특별자치도 서귀포시 표선면 표선리 2919',
#   '33.3079427982969',
#   '126.812424476454'],
#  ["블레블랑제리 Ble' Boulangerie",
#   '블레블랑제리',
#   '',
#   '제주특별자치도 제주시 아라일동 6097-17',
#   '33.4747403413465',
#   '126.54371973535'],
#  ['설심당본점',
#   '제주설심당 본점',
#   '064-745-2145',
#   '제주특별자치도 제주시 용담삼동 2319-6',
#   '33.5194348433794',
#   '126.492894953967'],
#  ['한라수목원',
#   '한라수목원',
#   '064-710-7575',
#   '제주특별자치도 제주시 연동 2484',
#   '33.4697839260314',
#   '126.493266082832'],
#  ['제주도 월정리',
#   '만장굴',
#   '064-710-7903',
#   '제주특별자치도 제주시 구좌읍 월정리 산 41-15',
#   '33.5283776001988',
#   '126.77161618452162'],
#  ['앙뚜아네트',
#   '앙뚜아네트 용담점',
#   '064-713-2220',
#   '제주특별자치도 제주시 용담삼동 503-5',
#   '33.5161848354525',
#   '126.508835277337'],
#  ['안녕김녕sea',
#   '안녕김녕씨',
#   '010-8060-3114',
#   '제주특별자치도 제주시 구좌읍 김녕리 6107-1',
#   '33.5593396451047',
#   '126.731374027033'],
#  ['돈사돈',
#   '돈사돈',
#   '064-739-9592',
#   '제주특별자치도 서귀포시 중문동 1884-7',
#   '33.2509771670023',
#   '126.433049252477'],
#  ['다람쥐식탁',
#   '다람쥐식탁',
#   '010-8386-9297',
#   '충북 음성군 금왕읍 무극리 662',
#   '36.9894933305423',
#   '127.585329749671'],
#  ['쿠주',
#   '쿠주',
#   '053-295-0156',
#   '대구 달성군 다사읍 죽곡리 825-5',
#   '35.851295203744',
#   '128.46811364306'],
#  ['제주국제공항',
#   '제주국제공항',
#   '1661-2626',
#   '제주특별자치도 제주시 용담2동 2002',
#   '33.5070789578184',
#   '126.492769004244'],
#  ['양가형제',
#   '양가형제',
#   '010-4938-5455',
#   '제주특별자치도 제주시 한경면 청수리 746-8',
#   '33.30735239828433',
#   '126.25398026094153'],
#  ['이익새양과점',
#   '이익새',
#   '070-4134-2343',
#   '제주특별자치도 제주시 한림읍 동명리 1576-7',
#   '33.4073649482759',
#   '126.265540410067'],
#  ['제주도 세화해변',
#   '세화해변',
#   '064-728-7752',
#   '제주특별자치도 제주시 구좌읍 세화리 1-1',
#   '33.5251436596119',
#   '126.86025618946'],
#  ['안녕협재씨',
#   '안녕협재씨 제주협재점',
#   '064-796-0624',
#   '제주특별자치도 제주시 한림읍 금능리 1740',
#   '33.38656924092464',
#   '126.22497882578234'],
#  ['제주도 해안도로',
#   '형제해안도로',
#   '',
#   '제주특별자치도 서귀포시 안덕면 사계리',
#   '33.2167542093081',
#   '126.293352563779'],
#  ['제주도 서귀포',
#   '올레길 7코스(서귀포-월평 올레)',
#   '',
#   '제주특별자치도 서귀포시 법환동 163-4',
#   '33.23738579332568',
#   '126.51530966206293'],
#  ['쇠소깍',
#   '쇠소깍',
#   '064-732-9998',
#   '제주특별자치도 서귀포시 하효동 990-1',
#   '33.25424606530691',
#   '126.62240514256442'],
#  ['애월늘',
#   '늘푸른빌라',
#   '',
#   '제주특별자치도 제주시 애월읍 하귀2리 1923',
#   '33.478240863178',
#   '126.401647952163'],
#  ['제주 한라산 영실코스',
#   '한라산국립공원 영실탐방로',
#   '064-713-9950',
#   '제주특별자치도 서귀포시 영남동',
#   '33.35948456480922',
#   '126.5128718702698'],
#  ['혜화동버거',
#   '혜화동버거',
#   '02-744-0125',
#   '서울 종로구 동숭동 130-63',
#   '37.5811284300394',
#   '127.004718685372'],
#  ['Jejudo',
#   '제주도드론',
#   '064-794-9530',
#   '제주특별자치도 서귀포시 안덕면 서광리 654',
#   '33.30912196385793',
#   '126.3277039068451'],
#  ['제주 산굼부리',
#   '산굼부리',
#   '064-783-9900',
#   '제주특별자치도 제주시 조천읍 교래리 166-2',
#   '33.4325740941816',
#   '126.69383199842952'],
#  ['대평리',
#   '거창만남의광장',
#   '',
#   '경남 거창군 거창읍 대평리 821',
#   '35.677678581704',
#   '127.926627666472'],
#  ['금능해변',
#   '금능해수욕장',
#   '064-728-3983',
#   '제주특별자치도 제주시 한림읍 금능리 2026',
#   '33.3904488156321',
#   '126.235889902253'],
#  ['다랑쉬오름',
#   '다랑쉬오름',
#   '',
#   '제주특별자치도 제주시 구좌읍 세화리 산 6',
#   '33.47768585996772',
#   '126.82153592461563'],
#  ['보름우스테이',
#   '보름우스테이',
#   '010-2964-0262',
#   '제주특별자치도 서귀포시 하효동 840',
#   '33.2569936969959',
#   '126.61633637075457'],
#  ['법환동',
#   '올레길 7코스(서귀포-월평 올레)',
#   '',
#   '제주특별자치도 서귀포시 법환동 163-4',
#   '33.23738579332568',
#   '126.51530966206293'],
#  ['로얄',
#   '로얄호텔서울',
#   '02-756-1112',
#   '서울 중구 명동1가 6-3',
#   '37.56425741599385',
#   '126.98560265367243'],
#  ['선녀와나무꾼',
#   '선녀와나무꾼 테마공원',
#   '064-784-9001',
#   '제주특별자치도 제주시 조천읍 선흘리 1997',
#   '33.4787929391846',
#   '126.703778647835'],
#  ['Hamdeok Jeju',
#   '함덕비치스테이제주',
#   '064-782-5660',
#   '제주특별자치도 제주시 조천읍 함덕리 1010',
#   '33.54327833790815',
#   '126.66336151213414'],
#  ['제주 남원리',
#   '남원큰엉해변',
#   '',
#   '제주특별자치도 서귀포시 남원읍 남원리 2379-3',
#   '33.2733501754907',
#   '126.703710044663'],
#  ['인생밥집',
#   '인생밥집',
#   '',
#   '경남 김해시 진영읍 의전리 185-2',
#   '35.2682670928097',
#   '128.754624289862'],
#  ['서귀포시 성산읍',
#   '올레길 1코스(시흥-광치기 올레)',
#   '',
#   '제주특별자치도 서귀포시 성산읍 시흥리',
#   '33.47866074455451',
#   '126.90636648646604'],
#  ['아름다운 제주도',
#   '아름다운리조트',
#   '064-782-1300',
#   '제주특별자치도 서귀포시 성산읍 시흥리 5',
#   '33.47518322730358',
#   '126.90999371571884'],
#  ['유동커피',
#   '유동커피',
#   '064-733-6662',
#   '제주특별자치도 서귀포시 서귀동 581-4',
#   '33.2445258834582',
#   '126.563800348044'],
#  ['구좌읍 평대리',
#   '비자림',
#   '064-710-7912',
#   '제주특별자치도 제주시 구좌읍 평대리 3161-1',
#   '33.4904083697986',
#   '126.80998754971'],
#  ['용연구름다리',
#   '용연구름다리',
#   '',
#   '제주특별자치도 제주시 용담이동 2581',
#   '33.51488231777168',
#   '126.51439436830435'],
#  ['이중섭 거리',
#   '이중섭거리',
#   '',
#   '제주특별자치도 서귀포시 서귀동 370-21',
#   '33.24761378125579',
#   '126.56400391121568'],
#  ['카페루핀',
#   '카페루핀',
#   '010-9344-2855',
#   '제주특별자치도 서귀포시 대정읍 상모리 87-2',
#   '33.21038626942035',
#   '126.29132509493701'],
#  ['성산갯마을식당',
#   '갯마을낙지',
#   '',
#   '경남 창원시 성산구 대방동 365-5',
#   '35.2076720466206',
#   '128.70791850822'],
#  ['Osulloc Tea Museum',
#   '오설록 티뮤지엄',
#   '064-794-5312',
#   '제주특별자치도 서귀포시 안덕면 서광리 1235-1',
#   '33.30591328662081',
#   '126.28948929546861'],
#  ['제주시 아라동',
#   '한라산국립공원',
#   '064-713-9950',
#   '제주특별자치도 제주시 오등동 산 182',
#   '33.3766655632143',
#   '126.54222094512'],
#  ['어조횟집',
#   '어조횟집',
#   '0507-1464-4012',
#   '제주특별자치도 서귀포시 성산읍 성산리 388-3',
#   '33.46044086591515',
#   '126.93081252042569'],
#  ['짱구분식',
#   '짱구분식',
#   '064-762-6389',
#   '제주특별자치도 서귀포시 서귀동 254-2',
#   '33.2501815866952',
#   '126.567090217045'],
#  ['김영갑갤러리 두모악',
#   '김영갑갤러리두모악',
#   '064-784-9907',
#   '제주특별자치도 서귀포시 성산읍 삼달리 437-5',
#   '33.3718952325506',
#   '126.854135898752'],
#  ['앤트러사이트 제주 한림점',
#   '앤트러사이트 제주한림점',
#   '064-796-7991',
#   '제주특별자치도 제주시 한림읍 동명리 1715',
#   '33.4077717708008',
#   '126.258149647652'],
#  ['평대우유차',
#   '평대우유차',
#   '010-6767-7355',
#   '제주특별자치도 제주시 조천읍 함덕리 1002-6',
#   '33.541280173550476',
#   '126.66828533072287'],
#  ['서울맛집',
#   '서울맛집',
#   '02-465-2533',
#   '서울 성동구 성수동2가 335-136',
#   '37.5383079971898',
#   '127.054025642442'],
#  ['Vadada 바다다',
#   '바다다',
#   '064-738-2882',
#   '제주특별자치도 서귀포시 대포동 2384',
#   '33.2369068490562',
#   '126.436715016074'],
#  ['이런날엔',
#   '이런날엔',
#   '070-4036-8013',
#   '제주특별자치도 제주시 구좌읍 한동리 1358-4',
#   '33.54253281448956',
#   '126.8306579838234'],
#  ['신설오름',
#   '신설오름',
#   '064-758-0143',
#   '제주특별자치도 제주시 일도이동 409-5',
#   '33.50541904737267',
#   '126.54156145724265'],
#  ['쌀다방',
#   '법환쌀다방',
#   '010-9367-3807',
#   '제주특별자치도 서귀포시 법환동 1259',
#   '33.2374811043814',
#   '126.511095770824'],
#  ['제주 윗세오름',
#   '한라산 웃세붉은오름',
#   '',
#   '제주특별자치도 서귀포시 서호동 산 183-1',
#   '33.3603553396532',
#   '126.520701746978'],
#  ['다미진횟집',
#   '다미진횟집',
#   '064-787-5050',
#   '제주특별자치도 서귀포시 표선면 표선리 40-51',
#   '33.3251030257766',
#   '126.84402800587'],
#  ['남원읍 신례리',
#   '동백포레스트',
#   '0507-1331-2102',
#   '제주특별자치도 서귀포시 남원읍 신례리 1767',
#   '33.300308154725585',
#   '126.63619814081831'],
#  ['Teddy Bear Museum - 제주 테디베어뮤지엄',
#   '테디베어뮤지엄 제주점',
#   '064-738-7600',
#   '제주특별자치도 서귀포시 색달동 2889',
#   '33.2502959457555',
#   '126.412163077718'],
#  ['가시식당',
#   '가시식당',
#   '064-787-1035',
#   '제주특별자치도 서귀포시 표선면 가시리 1898-5',
#   '33.3530600681391',
#   '126.771437983288'],
#  ['이호테우해변',
#   '이호테우해수욕장',
#   '064-728-3993',
#   '제주특별자치도 제주시 이호일동 1665-13',
#   '33.4973768007144',
#   '126.452690819027'],
#  ['외쿡식당',
#   '외쿡포차',
#   '',
#   '광주 동구 동명동 200-22',
#   '35.152505650333154',
#   '126.92406370383041'],
#  ['문치비',
#   '문치비 서귀포신시가지점',
#   '064-739-2560',
#   '제주특별자치도 서귀포시 강정동 172-2',
#   '33.252853717586',
#   '126.506038461521'],
#  ['훈이네고사리육개장',
#   '김재훈고사리육개장',
#   '064-752-2601',
#   '제주특별자치도 제주시 이도이동 2029-3',
#   '33.487960950923195',
#   '126.53392346271185'],
#  ['김녕회관',
#   '김녕회관',
#   '010-9398-8746',
#   '제주특별자치도 제주시 구좌읍 김녕리 1190-2',
#   '33.5558706714433',
#   '126.75592840283'],
#  ['말젯문',
#   '말젯문',
#   '',
#   '제주특별자치도 제주시 구좌읍 한동리 10-38',
#   '33.53842048846556',
#   '126.83523095335448'],
#  ['우도',
#   '우도',
#   '064-728-4333',
#   '제주특별자치도 제주시 우도면 연평리',
#   '33.5044199749505',
#   '126.955582257582'],
#  ['박물관이살아있다',
#   '박물관은살아있다 인사동점',
#   '02-2034-0600',
#   '서울 종로구 인사동 43',
#   '37.5717935364132',
#   '126.987276534799'],
#  ['군산오름',
#   '군산',
#   '',
#   '제주특별자치도 서귀포시 안덕면 창천리 산 3-1',
#   '33.253239609507396',
#   '126.36997030451425'],
#  ['성산일출봉',
#   '성산일출봉',
#   '064-783-0959',
#   '제주특별자치도 서귀포시 성산읍 성산리 78',
#   '33.4591349705437',
#   '126.940537521366'],
#  ['카페주비 - JUBI',
#   '카페주비',
#   '010-6368-7676',
#   '제주특별자치도 제주시 이호일동 634-3',
#   '33.5000629359461',
#   '126.460779452996'],
#  ['토스카나호텔',
#   '토스카나호텔',
#   '064-735-7001',
#   '제주특별자치도 서귀포시 강정동 3702-1',
#   '33.26562309357885',
#   '126.48440899034529'],
#  ['로맨틱무브',
#   '로맨틱무브',
#   '070-8884-6853',
#   '서울 마포구 동교동 153-16',
#   '37.55934160337756',
#   '126.92428308828849'],
#  ['한림칼국수',
#   '한림칼국수',
#   '070-8900-3339',
#   '제주특별자치도 제주시 한림읍 한림리 1328-15',
#   '33.4155670879451',
#   '126.261506447291'],
#  ['평대리 해변',
#   '평대리해수욕장',
#   '',
#   '제주특별자치도 제주시 구좌읍 평대리',
#   '33.5335267644776',
#   '126.840859977641'],
#  ['모슬 포항',
#   '모슬포항',
#   '',
#   '제주특별자치도 서귀포시 대정읍 하모리 770-28',
#   '33.2164674474575',
#   '126.250509085028'],
#  ['제주도 한경면',
#   '올레길 13코스(용수-저지 올레)',
#   '',
#   '제주특별자치도 제주시 한경면 조수리',
#   '33.328625315540165',
#   '126.21230336658091'],
#  ['서귀포흑돈',
#   '서귀포흑돈',
#   '064-767-9718',
#   '제주특별자치도 서귀포시 토평동 551-2',
#   '33.24787641313347',
#   '126.58220372828056'],
#  ['켄싱턴 제주호텔',
#   '조선호텔 그랜드조선 제주',
#   '064-738-6600',
#   '제주특별자치도 서귀포시 색달동 2101',
#   '33.25235805009302',
#   '126.40800175200575'],
#  ['순옥이네명가',
#   '순옥이네 명가 본점',
#   '064-743-4813',
#   '제주특별자치도 제주시 도두일동 2615-5',
#   '33.505515927922644',
#   '126.46498161971583'],
#  ['지오반니',
#   '지오반니',
#   '031-221-6842',
#   '경기 화성시 반월동 717-4',
#   '37.22163154658148',
#   '127.05138775660373'],
#  ['영육일삼',
#   '영육일삼',
#   '070-8830-9492',
#   '제주특별자치도 서귀포시 강정동 2637-1',
#   '33.234443064409',
#   '126.488340711676'],
#  ['함덕호랑이',
#   '호랑이',
#   '',
#   '제주특별자치도 제주시 조천읍 함덕리 1252',
#   '33.5422649863937',
#   '126.664039443492'],
#  ['센트로',
#   '센트로',
#   '070-8614-6245',
#   '제주특별자치도 서귀포시 서귀동 172-4',
#   '33.2466488975268',
#   '126.567579770359'],
#  ['CAFE E.P.L',
#   '카페이피엘 (휴업중)',
#   '064-764-6191',
#   '제주특별자치도 서귀포시 남원읍 위미리 3166-1',
#   '33.2751811821941',
#   '126.656989843032'],
#  ['모슬포항 만선식당',
#   '만선식당',
#   '064-794-6300',
#   '제주특별자치도 서귀포시 대정읍 하모리 770-50',
#   '33.2178625441496',
#   '126.249810687304'],
#  ['신창풍차해안도로',
#   '신창풍차해안도로',
#   '',
#   '제주특별자치도 제주시 한경면 신창리 1322-1',
#   '33.343081026740045',
#   '126.17420604655737'],
#  ['Hotel NANTA 호텔 난타',
#   '호텔난타',
#   '064-727-0602',
#   '제주특별자치도 제주시 오등동 10-1',
#   '33.4458269894688',
#   '126.547910794578'],
#  ['테지움 제주',
#   '테디베어하우스 테지움 제주점',
#   '064-799-4820',
#   '제주특별자치도 제주시 애월읍 소길리 155-106',
#   '33.412252132226875',
#   '126.39361326921566'],
#  ['목장카페 드르쿰다',
#   '목장카페드르쿰다',
#   '064-787-5220',
#   '제주특별자치도 서귀포시 표선면 성읍리 2873',
#   '33.4094597055704',
#   '126.77033789322249'],
#  ['삼미흑돼지',
#   '삼미흑돼지 중문점',
#   '064-739-9392',
#   '제주특별자치도 서귀포시 색달동 2275-1',
#   '33.2585789099797',
#   '126.413451221879'],
#  ['제주마방목지',
#   '제주축산진흥원 제주마 방목지',
#   '',
#   '제주특별자치도 제주시 용강동 산 14-34',
#   '33.42763738125047',
#   '126.60359603464576'],
#  ['그계절',
#   '그계절',
#   '010-3140-3121',
#   '제주특별자치도 제주시 구좌읍 한동리 2040',
#   '33.5318587572743',
#   '126.818530919106'],
#  ['판포포구',
#   '판포포구',
#   '',
#   '제주특별자치도 제주시 한경면 판포리',
#   '33.365021627537',
#   '126.200023263531'],
#  ['중문 덤장',
#   '덤장 중문점',
#   '064-738-2550',
#   '제주특별자치도 서귀포시 색달동 2119',
#   '33.2577350437998',
#   '126.408133975318'],
#  ['Longlive',
#   '롱리브',
#   '070-4247-7600',
#   '제주특별자치도 제주시 아라일동 6044-3',
#   '33.4765570711503',
#   '126.541524169251'],
#  ['문쏘',
#   '문쏘',
#   '0507-1350-7935',
#   '제주특별자치도 제주시 한림읍 옹포리 326-3',
#   '33.405687697267794',
#   '126.25670970996777'],
#  ['우동가게',
#   '우동가게',
#   '02-2634-2999',
#   '서울 영등포구 당산동4가 31-2',
#   '37.5302621509573',
#   '126.89933675316'],
#  ['하도리1091',
#   '라리저브독채펜션',
#   '010-2267-2449',
#   '제주특별자치도 제주시 구좌읍 하도리 1091-50',
#   '33.5103686092444',
#   '126.889163327806'],
#  ['성읍민속마을',
#   '제주성읍마을',
#   '064-710-6797',
#   '제주특별자치도 서귀포시 표선면 성읍리 855-1',
#   '33.384959730607484',
#   '126.8014989334944'],
#  ['대정읍',
#   '올레길 10코스(화순-모슬포 올레)',
#   '',
#   '제주특별자치도 서귀포시 대정읍 상모리',
#   '33.216890444802004',
#   '126.29320987840607'],
#  ['제주 도두동',
#   '올레길 17코스(광령-제주원도심 올레)',
#   '',
#   '제주특별자치도 제주시 도두일동',
#   '33.50563877194622',
#   '126.4726047828175'],
#  ['블리스찬',
#   '블리스찬',
#   '064-902-9770',
#   '제주특별자치도 제주시 오라이동 3295-10',
#   '33.4733445289836',
#   '126.503340845846'],
#  ['Salon de Lavant',
#   '살롱드라방',
#   '070-7797-3708',
#   '제주특별자치도 제주시 애월읍 하가리 1415',
#   '33.4578582644197',
#   '126.348969735405'],
#  ['황우지해안',
#   '황우지해안 (폐쇄)',
#   '064-760-4601',
#   '제주특별자치도 서귀포시 천지동 765-7',
#   '33.2414671811999',
#   '126.550527835146'],
#  ['새연교횟집',
#   '새연교횟집',
#   '064-767-0202',
#   '제주특별자치도 서귀포시 서귀동 633-4',
#   '33.2434541052246',
#   '126.56259103752'],
#  ['한림항',
#   '한림항',
#   '',
#   '제주특별자치도 제주시 한림읍 한림리',
#   '33.4146784560727',
#   '126.255828967781'],
#  ['오롯',
#   '오롯',
#   '010-5419-8220',
#   '제주특별자치도 제주시 아라이동 3009-5',
#   '33.4909893788423',
#   '126.544340522138'],
#  ['이정의댁',
#   '이정의댁',
#   '',
#   '제주특별자치도 서귀포시 상예동 1429',
#   '33.249670625142656',
#   '126.39199367651446'],
#  ['부두식당',
#   '부두식당',
#   '064-794-1223',
#   '제주특별자치도 서귀포시 대정읍 하모리 770-9',
#   '33.21893180292601',
#   '126.25099866644327'],
#  ['제주돌마을공원',
#   '제주돌마을공원',
#   '064-772-4007',
#   '제주특별자치도 제주시 한림읍 금능리 368-2',
#   '33.3540024518805',
#   '126.253604031769'],
#  ['천제연폭포',
#   '천제연폭포',
#   '064-760-6331',
#   '제주특별자치도 서귀포시 중문동 2232',
#   '33.25267658457861',
#   '126.41837541561675'],
#  ['선흘리 동백동산',
#   '동백동산',
#   '064-784-9445',
#   '제주특별자치도 제주시 조천읍 선흘리 산 12',
#   '33.5164508045545',
#   '126.716028545663'],
#  ['Cafe148',
#   '정암148카페',
#   '',
#   '강원특별자치도 양양군 강현면 정암리 148-2',
#   '38.13888055087778',
#   '128.61490431507616'],
#  ['백약이 오름',
#   '백약이오름',
#   '',
#   '제주특별자치도 서귀포시 표선면 성읍리 산 1',
#   '33.436809406991',
#   '126.789758231167'],
#  ['제주 휴애리',
#   '휴애리자연생활공원',
#   '064-732-2114',
#   '제주특별자치도 서귀포시 남원읍 신례리 2081',
#   '33.309410458656',
#   '126.635409752107'],
#  ['비브레이브 커피 로스터즈',
#   '비브레이브커피로스터즈',
#   '010-5751-6591',
#   '제주특별자치도 서귀포시 서호동 1525-2',
#   '33.25492909471123',
#   '126.51817574854293'],
#  ['가시아방',
#   '가시아방국수',
#   '064-783-0987',
#   '제주특별자치도 서귀포시 성산읍 고성리 528-2',
#   '33.43860508447686',
#   '126.91806478438669'],
#  ['제주시 동문시장',
#   '제주동문시장',
#   '',
#   '제주특별자치도 제주시 일도일동 1148-2',
#   '33.51278396493313',
#   '126.52830338722843'],
#  ['꽃기린 카페',
#   '꽃기린',
#   '062-524-3230',
#   '광주 북구 운암동 486-1',
#   '35.1754134698156',
#   '126.882111621013'],
#  ['판포리',
#   '판포오름',
#   '',
#   '제주특별자치도 제주시 한경면 판포리 934',
#   '33.3580646429918',
#   '126.213520892882'],
#  ['족황상제',
#   '족황상제 잠원본점',
#   '02-3477-1982',
#   '서울 서초구 잠원동 66-9',
#   '37.5088969024379',
#   '127.008622975925'],
#  ['그초록',
#   '그초록',
#   '010-7777-4244',
#   '제주특별자치도 제주시 구좌읍 행원리 1485-8',
#   '33.55638633245983',
#   '126.80639618389232'],
#  ['만세국수삼성혈점',
#   '제주도 고기국수 만세국수',
#   '064-727-7056',
#   '제주특별자치도 제주시 이도이동 1061-2',
#   '33.497666700991',
#   '126.537075075475'],
#  ['컴피하우스',
#   '컴피하우스',
#   '010-8685-7684',
#   '제주특별자치도 서귀포시 성산읍 온평리 1870',
#   '33.42536240305823',
#   '126.8966368878253'],
#  ['복자씨연탄구이',
#   '복자씨연탄구이',
#   '064-782-7330',
#   '제주특별자치도 서귀포시 성산읍 오조리 367-1',
#   '33.4692790800661',
#   '126.919897039456'],
#  ['이음',
#   '이음',
#   '070-4138-0150',
#   '서울 종로구 부암동 254-7',
#   '37.59250837117779',
#   '126.96530649471624'],
#  ['용두암',
#   '용두암',
#   '064-728-3917',
#   '제주특별자치도 제주시 용담2동 483',
#   '33.5161106216721',
#   '126.511957109074'],
#  ['아쿠아 플라넷 제주 (Aqua Planet JEJU)',
#   '아쿠아플라넷 제주',
#   '1833-7001',
#   '제주특별자치도 서귀포시 성산읍 고성리 127-3',
#   '33.433068041140075',
#   '126.92784588473428'],
#  ['소보리당로 222',
#   '소보리당로222',
#   '010-3832-7896',
#   '제주특별자치도 서귀포시 상예동 2850-5',
#   '33.2629222159358',
#   '126.38330535595469'],
#  ['제주 구좌읍 세화리',
#   '세화해변',
#   '064-728-7752',
#   '제주특별자치도 제주시 구좌읍 세화리 1-1',
#   '33.5251436596119',
#   '126.86025618946'],
#  ['스튜디오 쿠나',
#   '스튜디오쿠나',
#   '',
#   '제주특별자치도 제주시 애월읍 하귀2리 1873',
#   '33.48022517933131',
#   '126.40051214931798'],
#  ['남원읍 위미리 귤밭',
#   '오복이네귤밭',
#   '010-6562-0564',
#   '제주특별자치도 서귀포시 남원읍 신례리 712',
#   '33.2805620184647',
#   '126.628110004585'],
#  ['제주허브동산',
#   '제주허브동산',
#   '064-787-7362',
#   '제주특별자치도 서귀포시 표선면 표선리 2608',
#   '33.33039388694988',
#   '126.81518508108189'],
#  ['슬슬슬로우',
#   '슬슬슬로우',
#   '010-9261-9284',
#   '제주특별자치도 제주시 구좌읍 행원리 2306-12',
#   '33.53038703828247',
#   '126.79303509146435'],
#  ['아부오름',
#   '아부오름',
#   '',
#   '제주특별자치도 제주시 구좌읍 송당리 2263',
#   '33.4485841755621',
#   '126.777214998455'],
#  ['볼스카페',
#   '볼스카페',
#   '070-7779-1981',
#   '제주특별자치도 서귀포시 회수동 554-2',
#   '33.25328838235717',
#   '126.44250130435073'],
#  ['테쉬폰',
#   '테쉬폰카페',
#   '070-7778-8579',
#   '제주특별자치도 서귀포시 표선면 토산리 379',
#   '33.309382417038',
#   '126.781873509897'],
#  ['올레7코스',
#   '올레길 7코스(서귀포-월평 올레)',
#   '',
#   '제주특별자치도 서귀포시 법환동 163-4',
#   '33.23738579332568',
#   '126.51530966206293'],
#  ['상호네숯불구이',
#   '상호네숯불구이 본점',
#   '033-251-1170',
#   '강원특별자치도 춘천시 퇴계동 1189-5',
#   '37.86529659109587',
#   '127.72335830969678'],
#  ['테디베어뮤지엄',
#   '테디베어뮤지엄 제주점',
#   '064-738-7600',
#   '제주특별자치도 서귀포시 색달동 2889',
#   '33.2502959457555',
#   '126.412163077718'],
#  ['서귀포 까망돼지',
#   '까망돼지 중문점',
#   '064-738-6543',
#   '제주특별자치도 서귀포시 색달동 2534-9',
#   '33.2574066173646',
#   '126.413411836802'],
#  ['호텔 몽듀',
#   '몽듀호텔',
#   '',
#   '제주특별자치도 제주시 용담삼동 2572',
#   '33.51267451405757',
#   '126.4845402918902'],
#  ['제주도 천지연 폭포',
#   '천지연폭포',
#   '064-760-6304',
#   '제주특별자치도 서귀포시 서홍동 2565',
#   '33.24721231608811',
#   '126.55452234287986'],
#  ['모뉴에트',
#   '모뉴에트',
#   '010-5746-5316',
#   '제주특별자치도 제주시 구좌읍 종달리 748',
#   '33.4914819914411',
#   '126.902224926828'],
#  ['라온더마파크',
#   '더마파크',
#   '064-795-8080',
#   '제주특별자치도 제주시 한림읍 월림리 산 8',
#   '33.35553937710075',
#   '126.24150450951313'],
#  ['자매국수 노형점',
#   '자매국수',
#   '064-746-2222',
#   '제주특별자치도 제주시 이호일동 651-3',
#   '33.498577203781664',
#   '126.45914433997106'],
#  ['제주 이호해수욕장',
#   '이호테우해수욕장',
#   '064-728-3993',
#   '제주특별자치도 제주시 이호일동 1665-13',
#   '33.4973768007144',
#   '126.452690819027'],
#  ['그리울땐 제주',
#   '그리울땐제주',
#   '010-3697-9975',
#   '제주특별자치도 서귀포시 남원읍 신흥리 125-6',
#   '33.3009552852259',
#   '126.770581869754'],
#  ['천지연폭포',
#   '천지연폭포',
#   '064-760-6304',
#   '제주특별자치도 서귀포시 서홍동 2565',
#   '33.24721231608811',
#   '126.55452234287986'],
#  ['초밥충전',
#   '초밥충전',
#   '0507-1329-3840',
#   '제주특별자치도 서귀포시 안덕면 화순리 240-7',
#   '33.2482331036319',
#   '126.338913773455'],
#  ['연정식당',
#   '연정식당',
#   '064-747-3959',
#   '제주특별자치도 제주시 연동 256',
#   '33.4837678651428',
#   '126.486746198323'],
#  ['해왓',
#   '해왓',
#   '064-782-5689',
#   '제주특별자치도 서귀포시 성산읍 고성리 524-2',
#   '33.4384927031139',
#   '126.917189510552'],
#  ['제주서커스월드공연장',
#   '서커스월드공연장 전기차충전소',
#   '1899-2100',
#   '제주특별자치도 서귀포시 안덕면 동광리 886',
#   '33.31436400375418',
#   '126.34459613429026'],
#  ['로컬크랩',
#   '로컬크랩',
#   '064-782-2342',
#   '제주특별자치도 서귀포시 표선면 하천리 2011',
#   '33.36882360726549',
#   '126.8144344230491'],
#  ['제주시외버스터미널',
#   '제주시버스터미널',
#   '064-753-1153',
#   '제주특별자치도 제주시 오라일동 2441-1',
#   '33.499725778982096',
#   '126.5148804170176'],
#  ['봄날',
#   '봄날',
#   '061-745-0071',
#   '전남 순천시 덕월동 12-31',
#   '34.9244568098295',
#   '127.487230432248'],
#  ['대우정',
#   '대우정',
#   '064-757-9662',
#   '제주특별자치도 제주시 삼도일동 569-27',
#   '33.4989236665696',
#   '126.519586532616'],
#  ['갈중이',
#   '농업회사법인 갈중이',
#   '064-794-1686',
#   '제주특별자치도 서귀포시 안덕면 사계리 113',
#   '33.2350985952254',
#   '126.313658360193'],
#  ['밥의정석',
#   '밥의정석',
#   '070-8900-0507',
#   '제주특별자치도 서귀포시 동홍동 1329-1',
#   '33.261952382819004',
#   '126.56169179830941'],
#  ['바닐라파레트',
#   '바닐라파레트',
#   '010-2492-1106',
#   '제주특별자치도 제주시 노형동 763-8',
#   '33.4771172717429',
#   '126.480579828486'],
#  ['중문색달해변 (Jungmun Saekdal Beach)',
#   '중문색달해수욕장',
#   '064-738-4843',
#   '제주특별자치도 서귀포시 색달동 3039',
#   '33.2450381505136',
#   '126.411498674889'],
#  ['카페두가시',
#   '카페두가시',
#   '0507-1430-0171',
#   '제주특별자치도 서귀포시 안덕면 창천리 870-1',
#   '33.2354950659364',
#   '126.366642899065'],
#  ['따라비오름',
#   '따라비오름',
#   '',
#   '제주특별자치도 서귀포시 표선면 가시리 산 63',
#   '33.3887069884228',
#   '126.752858386101'],
#  ['아도록',
#   '아도록',
#   '',
#   '제주특별자치도 제주시 한경면 판포리 2594-1',
#   '33.35880368535034',
#   '126.20175404761244'],
#  ['한담해안산책로',
#   '한담해안산책로',
#   '',
#   '제주특별자치도 제주시 애월읍 곽지리 1359',
#   '33.4593234504188',
#   '126.310468326159'],
#  ['칠돈가',
#   '칠돈가 중문점',
#   '064-738-1195',
#   '제주특별자치도 서귀포시 색달동 2312-1',
#   '33.25746296459185',
#   '126.41446315642348'],
#  ['사라봉근처',
#   '난장게스트하우스',
#   '010-5617-0640',
#   '제주특별자치도 제주시 일도일동 1276-18',
#   '33.5153324500807',
#   '126.526095975281'],
#  ['함덕해변',
#   '함덕해수욕장',
#   '064-728-3989',
#   '제주특별자치도 제주시 조천읍 함덕리 1004-10',
#   '33.5430615661113',
#   '126.669238934013'],
#  ['난드르바당',
#   '난드르바당',
#   '064-739-0053',
#   '제주특별자치도 서귀포시 하예동 1798-4',
#   '33.234617382450736',
#   '126.37100510566297'],
#  ['Antoinette',
#   '앙뚜아네트 용담점',
#   '064-713-2220',
#   '제주특별자치도 제주시 용담삼동 503-5',
#   '33.5161848354525',
#   '126.508835277337'],
#  ['South Korea',
#   '에이엘에스인스펙션사우쓰코리아',
#   '052-237-2033',
#   '울산 울주군 온산읍 덕신리 572-29',
#   '35.4342191601958',
#   '129.3084893196511'],
#  ['형제국수',
#   '북청형제 원조국수집',
#   '010-8887-3639',
#   '인천 연수구 선학동 369-13',
#   '37.4235896024628',
#   '126.693893441784'],
#  ['애월더선셋',
#   '애월더선셋',
#   '064-799-5943',
#   '제주특별자치도 제주시 애월읍 곽지리 1381',
#   '33.4561265802926',
#   '126.30887594187952'],
#  ['제주도 전주횟집',
#   '전주횟집',
#   '064-712-1189',
#   '제주특별자치도 제주시 용담삼동 1144',
#   '33.5199704558597',
#   '126.496891715649'],
#  ['제주김만복',
#   '제주김만복 김밥 본점',
#   '064-759-8582',
#   '제주특별자치도 제주시 오라삼동 2250-1',
#   '33.4970353986304',
#   '126.508921919644'],
#  ['토끼썸',
#   '토끼썸',
#   '010-4628-4801',
#   '제주특별자치도 제주시 구좌읍 하도리 1',
#   '33.52192638345875',
#   '126.89881498224804'],
#  ['삼공주회센터',
#   '삼공주회센터',
#   '064-758-5392',
#   '제주특별자치도 제주시 화북일동 1562',
#   '33.5249386753043',
#   '126.568206397719'],
#  ['숨비아일랜드',
#   '숨비아일랜드',
#   '070-8851-1273',
#   '제주특별자치도 서귀포시 성산읍 신천리 353-16',
#   '33.3391570072211',
#   '126.855466622674'],
#  ['모메든식당',
#   '모메든식당 중문점',
#   '064-739-8205',
#   '제주특별자치도 서귀포시 하원동 1381-1',
#   '33.253494999251984',
#   '126.45452959390342'],
#  ['이게밥도둑',
#   '이게밥도둑',
#   '064-724-6321',
#   '제주특별자치도 제주시 연동 291-58',
#   '33.4916144376594',
#   '126.493543553666'],
#  ['쉐프부부',
#   '쉐프부부',
#   '064-712-7270',
#   '제주특별자치도 제주시 노형동 1278-11',
#   '33.48766651699844',
#   '126.4796517608005'],
#  ['지금여기',
#   '지금여기',
#   '',
#   '경남 남해군 남면 홍현리 955-1',
#   '34.7285363368474',
#   '127.893556606698'],
#  ['홍키호테',
#   '홍키호테',
#   '064-757-1929',
#   '제주특별자치도 제주시 아라일동 6154-5',
#   '33.471434471417815',
#   '126.54971538197508'],
#  ['카페모리&베이커스트리트',
#   '카페모리',
#   '042-284-2334',
#   '대전 동구 삼정동 8-6',
#   '36.3322404932921',
#   '127.479767648612'],
#  ['헤이브라더',
#   '헤이브라더',
#   '010-9234-0703',
#   '울산 중구 유곡동 117-22',
#   '35.5571685838321',
#   '129.306260696232'],
#  ['올레안뜰',
#   '올레안뜰',
#   '0507-1392-7723',
#   '제주특별자치도 서귀포시 법환동 229',
#   '33.237156429558',
#   '126.512911882397'],
#  ['젠하이드어웨이',
#   '젠하이드어웨이',
#   '064-794-0133',
#   '제주특별자치도 서귀포시 안덕면 사계리 2032-7',
#   '33.2292960867193',
#   '126.308502721338'],
#  ['소우',
#   '소우',
#   '063-583-3346',
#   '전북특별자치도 부안군 동진면 장등리 670-5',
#   '35.73946530225259',
#   '126.76350053847541'],
#  ['비스트로낭',
#   '비스트로낭',
#   '0507-1419-2933',
#   '제주특별자치도 서귀포시 안덕면 화순리 1053-128',
#   '33.249035066717276',
#   '126.32972886738733'],
#  ['수제홍과일모찌하귀점',
#   '수제홍과일모찌 애월하귀점',
#   '070-4548-5745',
#   '제주특별자치도 제주시 애월읍 하귀1리 195-11',
#   '33.4838883724507',
#   '126.413903925178'],
#  ['충남 대천 해수욕장 에서',
#   '대천해수욕장',
#   '041-933-7051',
#   '충남 보령시 신흑동 2267-3',
#   '36.3102317300706',
#   '126.513481592784'],
#  ['Jamae Guksu',
#   '자매국수',
#   '064-746-2222',
#   '제주특별자치도 제주시 이호일동 651-3',
#   '33.498577203781664',
#   '126.45914433997106'],
#  ['도라지식당',
#   '도라지식당',
#   '064-722-3142',
#   '제주특별자치도 제주시 오라삼동 2112',
#   '33.49270854222864',
#   '126.50594414126557'],
#  ['호박다방',
#   '호박다방',
#   '041-674-5549',
#   '충남 태안군 태안읍 남문리 702-15',
#   '36.7469130811872',
#   '126.303445583909'],
#  ['중문 단지 삼원정',
#   '삼원정 본점',
#   '064-738-1077',
#   '제주특별자치도 서귀포시 색달동 2285-7',
#   '33.259324949878014',
#   '126.4139184363266'],
#  ['마모루',
#   '마모루',
#   '064-722-4303',
#   '제주특별자치도 제주시 이도2동 1181-2',
#   '33.4988789047125',
#   '126.531441501793'],
#  ['카페바띠',
#   '바띠',
#   '010-4766-1349',
#   '제주특별자치도 서귀포시 남원읍 신흥리 242-9',
#   '33.3050550975492',
#   '126.767723521243'],
#  ['제주엠리조트',
#   '제주M리조트',
#   '1522-1782',
#   '제주특별자치도 서귀포시 강정동 1938',
#   '33.257779185401944',
#   '126.4943443201863'],
#  ['털보네고양이',
#   '털보네고양이',
#   '010-8647-8632',
#   '제주특별자치도 서귀포시 남원읍 위미리 165-10',
#   '33.2753778557836',
#   '126.687829830714'],
#  ['마구로쇼쿠도',
#   '마구로쇼쿠도',
#   '064-803-0199',
#   '제주특별자치도 제주시 이도이동 1958-5',
#   '33.4938713831499',
#   '126.546445295938'],
#  ['쿠쿠아림',
#   '쿠쿠아림',
#   '064-751-6645',
#   '제주특별자치도 제주시 아라일동 6064-8',
#   '33.46937443191051',
#   '126.541871816499'],
#  ['시루애월 소길점',
#   '시루애월',
#   '010-4191-3667',
#   '제주특별자치도 제주시 애월읍 장전리 634-1',
#   '33.44272720090267',
#   '126.3918247411162'],
#  ['제주시동문시장',
#   '제주동문시장',
#   '',
#   '제주특별자치도 제주시 일도일동 1148-2',
#   '33.51278396493313',
#   '126.52830338722843'],
#  ['삼다버거',
#   '삼다버거',
#   '',
#   '제주특별자치도 제주시 구좌읍 김녕리 4696',
#   '33.5482413382201',
#   '126.735702486445'],
#  ['마포식당',
#   '마포식당',
#   '02-417-5100',
#   '서울 송파구 송파동 97-6',
#   '37.50196506487032',
#   '127.11092118938987'],
#  ['홍대개미제주',
#   '홍대개미 제주노형점',
#   '064-748-3369',
#   '제주특별자치도 제주시 노형동 3782-7',
#   '33.48394353547706',
#   '126.47914896065815'],
#  ['카페송키',
#   '카페송키',
#   '010-4412-5221',
#   '제주특별자치도 제주시 삼도이동 1120-2',
#   '33.515114997730635',
#   '126.52019667845425'],
#  ['바당지기식당',
#   '바당지기',
#   '064-784-6258',
#   '제주특별자치도 제주시 구좌읍 월정리 30',
#   '33.554849029149054',
#   '126.79788071450572'],
#  ['서귀포 기억나는집',
#   '기억나는집',
#   '064-733-8500',
#   '제주특별자치도 서귀포시 서귀동 486-4',
#   '33.2450792298239',
#   '126.562188072497'],
#  ['버드나무집',
#   '버드나무집',
#   '064-782-9992',
#   '제주특별자치도 제주시 조천읍 함덕리 1002-25',
#   '33.54129671552933',
#   '126.66739378515229'],
#  ['소금바치 순이네',
#   '소금바치순이네',
#   '064-784-1230',
#   '제주특별자치도 제주시 구좌읍 종달리 42-5',
#   '33.50365240929026',
#   '126.91263326000902'],
#  ['아산 음봉',
#   '아산스파비스',
#   '041-539-2000',
#   '충남 아산시 음봉면 신수리 288-1',
#   '36.8560743845979',
#   '126.980596363598'],
#  ['하노이안브라더스',
#   '하노이안브라더스',
#   '064-752-7494',
#   '제주특별자치도 제주시 건입동 124-2',
#   '33.50962247734512',
#   '126.5435712917985'],
#  ['반딧불 한담',
#   '제주반딧불한담 애월점',
#   '064-799-0781',
#   '제주특별자치도 제주시 애월읍 애월리 2527-12',
#   '33.46331725259',
#   '126.31010539641'],
#  ['과일애',
#   '과일애',
#   '055-223-2600',
#   '경남 창원시 마산합포구 월영동 614-19',
#   '35.1749489711078',
#   '128.561561613215'],
#  ['제주 사랑분식',
#   '사랑분식',
#   '064-757-5058',
#   '제주특별자치도 제주시 일도일동 1144-12',
#   '33.5124719955156',
#   '126.527825048009'],
#  ['중문국수나라',
#   '중문국수나라',
#   '064-739-3772',
#   '제주특별자치도 서귀포시 중문동 1615',
#   '33.256254497087745',
#   '126.42541729734745'],
#  ['협재칼국수',
#   '협재칼국수',
#   '064-796-8107',
#   '제주특별자치도 제주시 한림읍 협재리 1908-2',
#   '33.3968090833636',
#   '126.244506163658'],
#  ['시민갈비',
#   '시민갈비',
#   '042-931-8012',
#   '대전 대덕구 신탄진동 155-14',
#   '36.447450929275995',
#   '127.43110319664466'],
#  ['우진해장국',
#   '우진해장국',
#   '064-757-3393',
#   '제주특별자치도 제주시 삼도이동 831',
#   '33.51151689656457',
#   '126.52000128027187'],
#  ['자갈자갈',
#   '자갈자갈',
#   '',
#   '경기 부천시 소사구 심곡본동 703-10',
#   '37.4773633722549',
#   '126.778492762123'],
#  ['제주시',
#   '올레길 17코스(광령-제주원도심 올레)',
#   '',
#   '제주특별자치도 제주시 도두일동',
#   '33.50563877194622',
#   '126.4726047828175'],
#  ['공천포 식당',
#   '공천포식당',
#   '064-767-2425',
#   '제주특별자치도 서귀포시 남원읍 신례리 27-5',
#   '33.2663875765224',
#   '126.642586419037'],
#  ['해바라기 분식',
#   '해바라기분식',
#   '064-753-2554',
#   '제주특별자치도 제주시 이도이동 1773-19',
#   '33.500227113116004',
#   '126.52914956385872'],
#  ['해비치호텔&리조트 - Haevichi hotel & resort',
#   '해비치 호텔&리조트 제주',
#   '064-780-8100',
#   '제주특별자치도 서귀포시 표선면 표선리 40-69',
#   '33.321441416991675',
#   '126.84467246291966'],
#  ['벵디',
#   '벵디',
#   '064-783-7827',
#   '제주특별자치도 제주시 구좌읍 평대리 2031-2',
#   '33.5377198075388',
#   '126.837170217769'],
#  ['Cafe카페인',
#   '카페인 수송점',
#   '010-9191-2480',
#   '전북특별자치도 군산시 수송동 878-7',
#   '35.9602243343274',
#   '126.71784651314'],
#  ['봉개동',
#   '절물자연휴양림',
#   '064-728-1510',
#   '제주특별자치도 제주시 봉개동 산 78-1',
#   '33.4391525898214',
#   '126.628011263739'],
#  ['쭈니창고',
#   '쭈니창고',
#   '041-555-7363',
#   '충남 천안시 동남구 신부동 802',
#   '36.820872405769',
#   '127.159707336267'],
#  ['모이세해장국',
#   '모이세해장국',
#   '02-718-0523',
#   '서울 마포구 용강동 122-6',
#   '37.5414375410379',
#   '126.941097504218'],
#  ['하례리 망장포구',
#   '망장포',
#   '',
#   '제주특별자치도 서귀포시 남원읍 하례리',
#   '33.2591950092477',
#   '126.639688035965'],
#  ['오조해녀의집',
#   '오조해녀의집',
#   '',
#   '제주특별자치도 서귀포시 성산읍 오조리 3',
#   '33.4697350161441',
#   '126.92229348123'],
#  ['쉼표',
#   '쉼표',
#   '',
#   '제주특별자치도 제주시 한림읍 협재리 1732',
#   '33.39521161644132',
#   '126.24186944438061'],
#  ['독개물항',
#   '독개물항 제주 한림 협재 본점',
#   '064-796-3966',
#   '제주특별자치도 제주시 한림읍 옹포리 593-1',
#   '33.4018902224406',
#   '126.251612539436'],
#  ['월정곰닭',
#   '월정곰닭',
#   '070-4138-0223',
#   '서울 마포구 상암동 2-279',
#   '37.5789880266161',
#   '126.895123215921'],
#  ['탑동마차',
#   '청춘마차',
#   '',
#   '제주특별자치도 제주시 삼도이동 1236-8',
#   '33.50617830602412',
#   '126.52366840094975'],
#  ['1342틈',
#   '일과삶사이틈',
#   '010-7476-0531',
#   '제주특별자치도 제주시 노형동 909-16',
#   '33.48708609861818',
#   '126.4842303329765'],
#  ['백리향백반',
#   '백리향',
#   '064-784-9600',
#   '제주특별자치도 제주시 조천읍 조천리 2342-1',
#   '33.53698342301974',
#   '126.63841705233897'],
#  ['푸릇프릍',
#   '푸릇프릍 제주점',
#   '010-3050-3455',
#   '제주특별자치도 제주시 아라일동 6114-10',
#   '33.475192479400455',
#   '126.54901278224888'],
#  ['북촌플레이스',
#   '북촌플레이스',
#   '064-782-1785',
#   '제주특별자치도 제주시 조천읍 북촌리 1602-8',
#   '33.5454913285824',
#   '126.688343646646'],
#  ['마레벤또',
#   '마레벤또',
#   '',
#   '제주특별자치도 제주시 애월읍 애월리 2501-1',
#   '33.46260818554157',
#   '126.31165137591421'],
#  ['도토리키친',
#   '도토리키친 본점',
#   '0507-1463-1021',
#   '제주특별자치도 제주시 삼도이동 1158-1',
#   '33.51538650964344',
#   '126.51860434812481'],
#  ['지붕위제주바다',
#   '지붕위제주바다',
#   '070-8875-7812',
#   '제주특별자치도 제주시 구좌읍 평대리 1878',
#   '33.5328407905861',
#   '126.837498029285'],
#  ['연화키친',
#   '연화키친',
#   '064-900-9733',
#   '제주특별자치도 제주시 애월읍 상가리 1697',
#   '33.4489603677522',
#   '126.343985644359'],
#  ['제주시농협하나로마트',
#   '하나로마트 제주점',
#   '064-729-1551',
#   '제주특별자치도 제주시 건입동 22',
#   '33.503582439416135',
#   '126.55289272432519'],
#  ['훈남횟집',
#   '훈남횟집',
#   '064-783-0083',
#   '제주특별자치도 제주시 조천읍 함덕리 1002-21',
#   '33.54208595338686',
#   '126.66785804080043'],
#  ['제주시청',
#   '제주시청',
#   '064-120',
#   '제주특별자치도 제주시 이도이동 1176-1',
#   '33.4995342412698',
#   '126.531171087129'],
#  ['바라크라',
#   '바라크라',
#   '064-721-3136',
#   '제주특별자치도 서귀포시 보목동 789-1',
#   '33.2415952821835',
#   '126.604145948421'],
#  ['제주도청',
#   '제주특별자치도청',
#   '064-120',
#   '제주특별자치도 제주시 연동 312-1',
#   '33.48891790333224',
#   '126.49822914119608'],
#  ['Bonte museum',
#   '본태박물관',
#   '064-792-8108',
#   '제주특별자치도 서귀포시 안덕면 상천리 380',
#   '33.30377089594179',
#   '126.39247966305703'],
#  ['제주 팜스빌리지',
#   '팜스빌리지',
#   '010-9488-5566',
#   '제주특별자치도 제주시 한림읍 귀덕리 3116',
#   '33.4425954531532',
#   '126.285313182189'],
#  ['김녕장',
#   '김녕장게스트하우스',
#   '',
#   '제주특별자치도 제주시 구좌읍 김녕리 1579-1',
#   '33.5565466392379',
#   '126.74949548265'],
#  ['서귀포 워터월드',
#   '제주워터월드 휴업중',
#   '',
#   '제주특별자치도 서귀포시 법환동 914',
#   '33.24550727132407',
#   '126.50854558896376'],
#  ['오설록',
#   '오설록 티뮤지엄',
#   '064-794-5312',
#   '제주특별자치도 서귀포시 안덕면 서광리 1235-1',
#   '33.30591328662081',
#   '126.28948929546861'],
#  ['상효원 수목원',
#   '상효원수목원',
#   '064-733-2200',
#   '제주특별자치도 서귀포시 상효동 산 25',
#   '33.3059583755486',
#   '126.584635005756'],
#  ['애월해안도로',
#   '애월해안도로',
#   '',
#   '제주특별자치도 제주시 애월읍 신엄리 2719-3',
#   '33.4781232943703',
#   '126.36867872098'],
#  ['안녕, 육지사람',
#   '안녕육지사람',
#   '010-2823-0170',
#   '제주특별자치도 제주시 우도면 연평리 1197-4',
#   '33.515121670527996',
#   '126.95720423409409'],
#  ['제주롯데시네마',
#   '롯데시네마 제주아라',
#   '1544-8855',
#   '제주특별자치도 제주시 아라일동 2574',
#   '33.4838246695671',
#   '126.535908152018'],
#  ['Soror',
#   '제주소로르',
#   '',
#   '제주특별자치도 제주시 이도이동 1181-6',
#   '33.49821921819282',
#   '126.53175390477361'],
#  ['신창해안도로',
#   '신창풍차해안도로',
#   '',
#   '제주특별자치도 제주시 한경면 신창리 1322-1',
#   '33.343081026740045',
#   '126.17420604655737'],
#  ['다이브스테이',
#   '다이브스테이',
#   '010-6390-3452',
#   '제주특별자치도 서귀포시 하효동 1076-2',
#   '33.2536861514236',
#   '126.619741905076'],
#  ['금악리 제주힐링리조트',
#   '제주힐링리조트',
#   '064-796-3533',
#   '제주특별자치도 제주시 한림읍 금악리 3399',
#   '33.3463453150256',
#   '126.28206680334173'],
#  ['고근산정상',
#   '고근산',
#   '',
#   '제주특별자치도 서귀포시 서호동 1286-1',
#   '33.26679186408771',
#   '126.51287193493305'],
#  ['효돈마을',
#   '하효새마을작은도서관',
#   '064-767-3500',
#   '제주특별자치도 서귀포시 하효동 236',
#   '33.2620075127123',
#   '126.618924543626'],
#  ['서건도',
#   '서건도',
#   '',
#   '제주특별자치도 서귀포시 강정동 산 1',
#   '33.2299948343901',
#   '126.498627156523'],
#  ['외돌개',
#   '외돌개',
#   '',
#   '제주특별자치도 서귀포시 서홍동 791',
#   '33.2390338150319',
#   '126.544862271566'],
#  ['Seosan',
#   'MASJID ATTAUBAH SEOSAN',
#   '',
#   '충남 서산시 동문동 895-17',
#   '36.7814052783056',
#   '126.456420317236'],
#  ['에코그린리조트',
#   '에코그린리조트',
#   '064-796-8333',
#   '제주특별자치도 제주시 한림읍 귀덕리 1502',
#   '33.43528831814656',
#   '126.29147883038122'],
#  ['구엄리 돌염전',
#   '돌염전',
#   '',
#   '제주특별자치도 제주시 애월읍 구엄리',
#   '33.4834138275298',
#   '126.37652048642'],
#  ['Ramada Plaza Jeju',
#   '라마다프라자 제주호텔',
#   '064-729-8100',
#   '제주특별자치도 제주시 삼도이동 1254',
#   '33.51878081111122',
#   '126.51809364015251'],
#  ['골목카페 옥수',
#   '골목카페옥수',
#   '010-5520-6516',
#   '제주특별자치도 제주시 애월읍 소길리 652-1',
#   '33.4397509795262',
#   '126.379977434507'],
#  ['고기마씸',
#   '충세흑돼지고기마씸',
#   '064-747-6041',
#   '제주특별자치도 제주시 도련일동 1769-5',
#   '33.51164725208651',
#   '126.58882971804407'],
#  ['협재술시',
#   '협재술시',
#   '010-2574-0684',
#   '제주특별자치도 제주시 한림읍 협재리 2527',
#   '33.3924859186901',
#   '126.241099906859'],
#  ['구좌상회',
#   '구좌상회',
#   '010-6600-6648',
#   '제주특별자치도 제주시 조천읍 선흘리 3983',
#   '33.485688289936014',
#   '126.6988723691466'],
#  ['깡촌흑돼지',
#   '깡촌흑돼지 함덕본점',
#   '064-784-0787',
#   '제주특별자치도 제주시 조천읍 함덕리 1001',
#   '33.541274383213',
#   '126.667135470078'],
#  ['제주도 용두암',
#   '용두암',
#   '064-728-3917',
#   '제주특별자치도 제주시 용담2동 483',
#   '33.5161106216721',
#   '126.511957109074'],
#  ['Ocean Suites Jeju Hotel',
#   '오션스위츠제주호텔',
#   '1577-9766',
#   '제주특별자치도 제주시 삼도이동 1260-1',
#   '33.51814920658691',
#   '126.52309152230318'],
#  ['전주콩나물국밥',
#   '전주콩나물국밥',
#   '051-941-1232',
#   '부산 강서구 대저2동 2407-4',
#   '35.1748834063223',
#   '128.950518146314'],
#  ['박물관은 살아있다 제주 중문',
#   '박물관은살아있다 제주중문점',
#   '064-805-0888',
#   '제주특별자치도 서귀포시 색달동 2629',
#   '33.25492848172',
#   '126.408740973085'],
#  ['명진전복',
#   '명진전복',
#   '064-782-9944',
#   '제주특별자치도 제주시 구좌읍 평대리 515-28',
#   '33.5324709034017',
#   '126.850184971014'],
#  ['하도해변',
#   '하도해변',
#   '064-728-3394',
#   '제주특별자치도 제주시 구좌읍 하도리',
#   '33.5130567680421',
#   '126.899230006514'],
#  ['송당리 풍림다방',
#   '풍림다방 송당점',
#   '',
#   '제주특별자치도 제주시 구좌읍 송당리 1377-1',
#   '33.471878655079',
#   '126.785708132282'],
#  ['호연스테이',
#   '호연스테이',
#   '',
#   '제주특별자치도 제주시 구좌읍 한동리 1375-1',
#   '33.542372893772',
#   '126.829753877684'],
#  ['한성식당',
#   '한성식당',
#   '02-752-2056',
#   '서울 중구 서소문동 53-1',
#   '37.563260528947',
#   '126.973098147371'],
#  ['제주항공',
#   '제주항공 서울지사',
#   '1599-1500',
#   '서울 강서구 공항동 1373',
#   '37.553744090034165',
#   '126.80896554640965'],
#  ['스물다섯',
#   '스물다섯',
#   '064-748-3334',
#   '제주특별자치도 제주시 노형동 1275-11',
#   '33.48904453445883',
#   '126.4808185246333'],
#  ['Cafe가호',
#   '카페 가호',
#   '',
#   '제주특별자치도 제주시 애월읍 하귀2리 2721-4',
#   '33.48473867468726',
#   '126.39056077232941'],
#  ['카페소금',
#   '카페소금',
#   '0507-1428-5541',
#   '제주특별자치도 제주시 애월읍 구엄리 1285-1',
#   '33.482520797113',
#   '126.376070692854'],
#  ['네이처트레일',
#   '네이처트레일',
#   '',
#   '제주특별자치도 제주시 한림읍 금능리 1842-6',
#   '33.3826154100218',
#   '126.22535350484'],
#  ['반디앤로제이',
#   '반디앤로제이',
#   '010-2978-1128',
#   '제주특별자치도 제주시 조천읍 조천리 932-1',
#   '33.545368059777424',
#   '126.64146155172996'],
#  ['카페라능',
#   '카페산',
#   '1644-4674',
#   '충북 단양군 가곡면 사평리 246-33',
#   '36.9946987212414',
#   '128.394365136642'],
#  ['대구국제공항',
#   '대구국제공항',
#   '1661-2626',
#   '대구 동구 지저동 400-5',
#   '35.89984054200828',
#   '128.63783835924795'],
#  ['이중섭 미술관',
#   '이중섭미술관',
#   '064-760-3567',
#   '제주특별자치도 서귀포시 서귀동 532-1',
#   '33.2459037788334',
#   '126.564887992506'],
#  ['타시텔레',
#   '타시텔레 힐링농원',
#   '',
#   '제주특별자치도 서귀포시 표선면 가시리 1738',
#   '33.35740738048694',
#   '126.77422436757219'],
#  ['사락',
#   '사락',
#   '',
#   '제주특별자치도 서귀포시 안덕면 사계리 2069',
#   '33.2287707148007',
#   '126.30774087672'],
#  ['모던하우스 제주점',
#   '모던하우스 제주아라점',
#   '064-759-9265',
#   '제주특별자치도 제주시 아라일동 2567',
#   '33.484367275092815',
#   '126.5346646789013'],
#  ['돈사돈중문점',
#   '돈사돈 중문점 전용주차장',
#   '',
#   '제주특별자치도 서귀포시 중문동 1884-7',
#   '33.2507975242915',
#   '126.433001050878'],
#  ['썬앤문리조트',
#   '썬앤문리조트',
#   '064-794-6633',
#   '제주특별자치도 서귀포시 안덕면 사계리 2166-3',
#   '33.22737175361468',
#   '126.30103091562549'],
#  ['73st',
#   '73st',
#   '064-748-7309',
#   '제주특별자치도 제주시 해안동 1977-1',
#   '33.45699074238026',
#   '126.45510883544576'],
#  ['서귀포 칼호텔 (KAL Hotel Seogwipo)',
#   '서귀포KAL호텔',
#   '064-733-2001',
#   '제주특별자치도 서귀포시 토평동 486-3',
#   '33.24648461203475',
#   '126.58176182117475'],
#  ['성산포',
#   '성산포항',
#   '',
#   '제주특별자치도 서귀포시 성산읍 성산리',
#   '33.4734596563682',
#   '126.933293813424'],
#  ['제주카페 스르륵',
#   '제주카페스르륵',
#   '064-9999-9999',
#   '제주특별자치도 서귀포시 강정동 5623',
#   '33.2322645302471',
#   '126.463259298039'],
#  ['나주혁신도시',
#   '전라남도 혁신도시지원단',
#   '061-286-8822',
#   '전남 나주시 빛가람동 279-2',
#   '35.0207569927462',
#   '126.793336295329'],
#  ['playce',
#   'VR플레이스 김해외동점',
#   '',
#   '경남 김해시 외동 1258-5',
#   '35.232218523588',
#   '128.866966483757'],
#  ['하늘고래',
#   '하늘고래',
#   '010-9657-2204',
#   '제주특별자치도 제주시 한림읍 협재리 1436',
#   '33.3994584436266',
#   '126.246069769825'],
#  ['신천목장',
#   '신풍목장',
#   '',
#   '제주특별자치도 서귀포시 성산읍 신풍리 33',
#   '33.35601232414165',
#   '126.86373304959253'],
#  ['섭지코지 (Seopjikoji)',
#   '섭지코지',
#   '064-784-2810',
#   '제주특별자치도 서귀포시 성산읍 고성리 87',
#   '33.4239380655993',
#   '126.930609241011'],
#  ['제주좋은날',
#   '제주좋은날',
#   '010-6783-3305',
#   '제주특별자치도 제주시 애월읍 곽지리 1903',
#   '33.4456741591374',
#   '126.309948273867'],
#  ['벵디1967',
#   '벵디1967',
#   '010-4117-6278',
#   '제주특별자치도 제주시 구좌읍 평대리 1967',
#   '33.53500265194748',
#   '126.83805596820805'],
#  ['우도 비양도',
#   '비양도망대',
#   '',
#   '제주특별자치도 제주시 우도면 연평리',
#   '33.515409238245',
#   '126.969199001247'],
#  ['헤밍웨이 하우스',
#   '헤밍웨이하우스',
#   '',
#   '서울 성북구 정릉동 412-33',
#   '37.6064070508953',
#   '127.01189923237763'],
#  ['조천읍 북촌리',
#   '올레길 19코스(조천-김녕 올레)',
#   '',
#   '제주특별자치도 제주시 조천읍 북촌리 1179-1',
#   '33.54625032708214',
#   '126.6890041888081'],
#  ['제주도립미술관',
#   '제주도립미술관',
#   '064-710-4300',
#   '제주특별자치도 제주시 연동 680-7',
#   '33.4525846506737',
#   '126.489644694081'],
#  ['협재',
#   '협재해수욕장',
#   '064-728-3981',
#   '제주특별자치도 제주시 한림읍 협재리 2447',
#   '33.3938660776221',
#   '126.239157539085'],
#  ['제주인에이에이',
#   '에이쉘인제주',
#   '',
#   '제주특별자치도 서귀포시 하예동 1737-1',
#   '33.2348030276503',
#   '126.373846906176'],
#  ['제주도 표선',
#   '올레길 4코스(표선-남원 올레)',
#   '',
#   '제주특별자치도 서귀포시 표선면 표선리',
#   '33.30481622383354',
#   '126.78792799112594'],
#  ['Paz',
#   '파츠헤어',
#   '',
#   '서울 노원구 상계동 1318',
#   '37.6601104823279',
#   '127.069109881021'],
#  ['제주 성산읍',
#   '올레길 1코스(시흥-광치기 올레)',
#   '',
#   '제주특별자치도 서귀포시 성산읍 시흥리',
#   '33.47866074455451',
#   '126.90636648646604'],
#  ['방주교회',
#   '방주교회',
#   '064-794-0611',
#   '제주특별자치도 서귀포시 안덕면 상천리 427',
#   '33.305048981119',
#   '126.387439255121'],
#  ['카이로스 제주',
#   '카이로스',
#   '064-799-2299',
#   '제주특별자치도 제주시 애월읍 장전리 49-17',
#   '33.449262850826',
#   '126.400155234663'],
#  ['TheFirst70 Hotel',
#   '더퍼스트70호텔',
#   '064-766-0000',
#   '제주특별자치도 서귀포시 서귀동 182',
#   '33.24725582810093',
#   '126.5668406727831'],
#  ['ECOLAND theme park',
#   '에코랜드테마파크',
#   '064-802-8000',
#   '제주특별자치도 제주시 조천읍 교래리 385-1',
#   '33.4483387252476',
#   '126.670278657345'],
#  ['켄싱턴리조트 서귀포',
#   '켄싱턴리조트 서귀포',
#   '064-739-9001',
#   '제주특별자치도 서귀포시 강정동 2677',
#   '33.2337752320623',
#   '126.489065573321'],
# ...
#   '제주특별자치도 서귀포시 대포동 2238',
#   '33.2420747813875',
#   '126.443887961606'],
#  ['세인트포cc',
#   '아난티클럽제주',
#   '064-786-3800',
#   '제주특별자치도 제주시 구좌읍 김녕리 5160-2',
#   '33.5205468771983',
#   '126.738606953081'],
#  ['여수 앞바다',
#   '여수앞바다',
#   '031-861-1772',
#   '경기 양주시 덕정동 346-11',
#   '37.84050938080449',
#   '127.06276247097124'],
#  ['무거버거',
#   '무거버거',
#   '0507-1319-5076',
#   '제주특별자치도 제주시 조천읍 신흥리 15',
#   '33.548984211344525',
#   '126.65506337446807'],
#  ['유리네 식당',
#   '유리네식당',
#   '064-748-0890',
#   '제주특별자치도 제주시 연동 427-1',
#   '33.48146941480237',
#   '126.49701111225333'],
#  ['화산양꼬치2호점',
#   '화산양꼬치 2호점',
#   '064-756-5889',
#   '제주특별자치도 제주시 이도이동 1768-30',
#   '33.498595174695744',
#   '126.52984712438021'],
#  ['달달콤콤',
#   '달달콤콤',
#   '02-2222-2222',
#   '제주특별자치도 서귀포시 하효동 314',
#   '33.2622360636154',
#   '126.620541983252'],
#  ['규태네 양곱창',
#   '규태네양곱창 남녕점',
#   '064-748-9266',
#   '제주특별자치도 제주시 노형동 1274-1',
#   '33.4898090648177',
#   '126.480813962343'],
#  ['KBS본관',
#   'KBS 본관',
#   '02-781-1000',
#   '서울 영등포구 여의도동 18',
#   '37.52470211311498',
#   '126.91674992301569'],
#  ['쇠소깍오메기식당',
#   '쇠소깍오메기식당',
#   '064-732-5599',
#   '제주특별자치도 서귀포시 신효동 1093',
#   '33.2601002612173',
#   '126.607522516229'],
#  ['배블리컨테이너',
#   '배블리컨테이너',
#   '062-360-1939',
#   '광주 서구 광천동 49-1',
#   '35.1606019754615',
#   '126.882645565262'],
#  ['Cafe Ri',
#   '리카페',
#   '',
#   '경남 양산시 물금읍 가촌리 1249-3',
#   '35.3197749610677',
#   '128.996358916285'],
#  ['카페오길',
#   '카페오길',
#   '',
#   '울산 동구 전하동 677-3',
#   '35.5076412451734',
#   '129.426607904284'],
#  ['풍원 한라산볶음밥',
#   '풍원',
#   '064-784-1894',
#   '제주특별자치도 제주시 우도면 연평리 2427-1',
#   '33.508306597212',
#   '126.94399102084'],
#  ['홍대부부',
#   '협재문어떡볶이 홍대부부',
#   '',
#   '제주특별자치도 제주시 한림읍 협재리 1750',
#   '33.393732712545955',
#   '126.24152544617657'],
#  ['성읍칠십리식당',
#   '성읍칠십리식당',
#   '064-787-0911',
#   '제주특별자치도 서귀포시 표선면 성읍리 580',
#   '33.38919964266133',
#   '126.8012485433902'],
#  ['자구내포구',
#   '차귀도포구',
#   '',
#   '제주특별자치도 제주시 한경면 고산리 3616-15',
#   '33.3093132718988',
#   '126.165372766829'],
#  ['남포커피',
#   '투썸플레이스 부산남포점',
#   '051-257-8171',
#   '부산 중구 남포동4가 2-2',
#   '35.09832553227973',
#   '129.03151026645165'],
#  ['크랩잭제주',
#   '크랩잭',
#   '',
#   '제주특별자치도 제주시 애월읍 애월리 2546',
#   '33.462924778872775',
#   '126.30924473774489'],
#  ['마로니에 공원',
#   '마로니에공원',
#   '02-2148-4158',
#   '서울 종로구 동숭동 1-124',
#   '37.5802887643268',
#   '127.002825745303'],
#  ['제주 신재생에너지 홍보관',
#   '제주에너지공사 CFI에너지미래관',
#   '064-720-7490',
#   '제주특별자치도 제주시 구좌읍 행원리 21',
#   '33.5592846290016',
#   '126.818068671183'],
#  ['한림 바당길',
#   '바당길',
#   '064-796-1658',
#   '제주특별자치도 제주시 한림읍 한림리 1475-10',
#   '33.4097502897356',
#   '126.258524133858'],
#  ['연동포차',
#   '연동포차',
#   '',
#   '전남 순천시 연향동 1350-6',
#   '34.949491717569565',
#   '127.51626883694207'],
#  ['양대곱',
#   '백성원해장국 본점',
#   '064-724-0792',
#   '제주특별자치도 제주시 이도이동 1176-114',
#   '33.5013198139428',
#   '126.531281991926'],
#  ['깐깐한족발',
#   '깐깐한족발 광주첨단본점',
#   '062-973-2292',
#   '광주 광산구 월계동 886-3',
#   '35.21569495362731',
#   '126.84527283633469'],
#  ['오는정 김밥',
#   '오는정김밥',
#   '064-762-8927',
#   '제주특별자치도 서귀포시 서귀동 254-6',
#   '33.2495955703083',
#   '126.567621058572'],
#  ['뽕끄랑',
#   '뽕끄랑',
#   '064-763-3930',
#   '제주특별자치도 서귀포시 서홍동 644-10',
#   '33.2430344682521',
#   '126.555112221785'],
#  ['삼보식당',
#   '삼보식당',
#   '064-762-3620',
#   '제주특별자치도 서귀포시 서귀동 319-8',
#   '33.24768024521738',
#   '126.55907184469622'],
#  ['주점부리',
#   '주점부리 신양본점',
#   '',
#   '제주특별자치도 서귀포시 성산읍 고성리 206-8',
#   '33.436607929959365',
#   '126.92213698049497'],
#  ['수월봉',
#   '수월봉',
#   '',
#   '제주특별자치도 제주시 한경면 고산리 3760',
#   '33.29476974463891',
#   '126.16310858641053'],
#  ['흑돼지가있는풍경',
#   '흑돼지가있는풍경 본점',
#   '064-742-1108',
#   '제주특별자치도 제주시 노형동 668',
#   '33.475375671553',
#   '126.480646164645'],
#  ['물꼬기',
#   '물꼬기',
#   '02-6368-2300',
#   '서울 강북구 수유동 535-82',
#   '37.6430227744818',
#   '127.004577565908'],
#  ['대우정식당',
#   '대우정',
#   '064-757-9662',
#   '제주특별자치도 제주시 삼도일동 569-27',
#   '33.4989236665696',
#   '126.519586532616'],
#  ['청루 봉평 메밀 막국수',
#   '청루 봉평메밀막국수전문점',
#   '064-792-1238',
#   '제주특별자치도 서귀포시 대정읍 인성리 268-6',
#   '33.2489094503623',
#   '126.281397703114'],
#  ['큰돈가',
#   '큰돈가 중문점',
#   '064-739-0722',
#   '제주특별자치도 서귀포시 색달동 2505-2',
#   '33.25513719083029',
#   '126.41512469546467'],
#  ['모니카옛날통닭',
#   '모니카옛날통닭',
#   '064-747-6801',
#   '제주특별자치도 제주시 연동 2312-3',
#   '33.492955629376524',
#   '126.4890593307041'],
#  ['메이즈랜드',
#   '메이즈랜드',
#   '064-784-3838',
#   '제주특별자치도 제주시 구좌읍 평대리 3322',
#   '33.4882554533079',
#   '126.800871928106'],
#  ['소렉',
#   '소렉',
#   '010-5014-6068',
#   '제주특별자치도 제주시 연동 272-37',
#   '33.488195354961825',
#   '126.49128233145652'],
#  ['토도',
#   '토도',
#   '031-821-5200',
#   '경기 양주시 삼숭동 542-5',
#   '37.8096149374528',
#   '127.09473983112'],
#  ['인사리',
#   '인사교회',
#   '',
#   '인천 강화군 교동면 인사리 806',
#   '37.8117881662618',
#   '126.259816461218'],
#  ['제주시 고요남',
#   '고요남 제주점',
#   '064-722-5253',
#   '제주특별자치도 제주시 아라일동 6036-1',
#   '33.485569204888954',
#   '126.53589454402163'],
#  ['해녀엄마의집',
#   '해녀엄마의집',
#   '064-783-3534',
#   '제주특별자치도 서귀포시 성산읍 고성리 556-3',
#   '33.43608046959792',
#   '126.91791660464978'],
#  ['서촌제',
#   '서촌제',
#   '02-1670-8649',
#   '서울 송파구 잠실동 1-2',
#   '37.5192087548234',
#   '127.076508893563'],
#  ['제주 오션스토리',
#   '제주 오션스토리',
#   '064-783-8982',
#   '제주특별자치도 서귀포시 성산읍 온평리 520-1',
#   '33.411502768429',
#   '126.898827102644'],
#  ['은실이네 게스트하우스',
#   '은실이네게스트하우스',
#   '010-7588-4454',
#   '제주특별자치도 제주시 조천읍 함덕리 1049-1',
#   '33.5428693944831',
#   '126.662176586574'],
#  ['면뽑는선생 만두빚는아내',
#   '면뽑는선생만두빚는아내',
#   '064-796-4562',
#   '제주특별자치도 제주시 한림읍 협재리 1398',
#   '33.39974716015132',
#   '126.24937579046478'],
#  ['바다이야기',
#   '바다이야기',
#   '064-796-3444',
#   '제주특별자치도 제주시 한림읍 옹포리 571',
#   '33.4033458147276',
#   '126.25198273649'],
#  ['칠돈가 본점',
#   '칠돈가 본점',
#   '064-743-1222',
#   '제주특별자치도 제주시 노형동 1112',
#   '33.49387257074931',
#   '126.47760453822777'],
#  ['에이그라운드',
#   '에이그라운드',
#   '',
#   '제주특별자치도 서귀포시 성산읍 난산리 2679-6',
#   '33.4150676960228',
#   '126.836272766003'],
#  ['제주칼국수 제주해물탕',
#   '제주해물탕&아귀찜 갈매본점',
#   '031-571-5045',
#   '경기 구리시 갈매동 646',
#   '37.630775066427724',
#   '127.1173624196343'],
#  ['촵촵 - Chwap Chwap',
#   '촵촵',
#   '0507-1321-6468',
#   '제주특별자치도 제주시 이도이동 1962-8',
#   '33.49350867548493',
#   '126.54538833272214'],
#  ['행원포구',
#   '행원포구',
#   '',
#   '제주특별자치도 제주시 구좌읍 행원리',
#   '33.5564199908232',
#   '126.807745416685'],
#  ['신흥동 일본식가옥',
#   '신흥동일본식가옥',
#   '063-454-3267',
#   '전북특별자치도 군산시 신흥동 58-2',
#   '35.9861696060316',
#   '126.706057532726'],
#  ['이스트엔드',
#   '이스트엔드',
#   '070-4124-4999',
#   '서울 성동구 성수동1가 8-6',
#   '37.54670803042388',
#   '127.0477173686719'],
#  ['키작은삼촌',
#   '키작은삼촌',
#   '064-783-3502',
#   '제주특별자치도 서귀포시 성산읍 고성리 1012-1',
#   '33.44437796330059',
#   '126.9125690458407'],
#  ['고관해물탕, 초량',
#   '고관해물탕',
#   '051-463-7585',
#   '부산 동구 수정동 96-7',
#   '35.1264245039584',
#   '129.04519957858'],
#  ['브라운스위트 제주',
#   '브라운스위트제주 호텔앤리조트',
#   '064-786-6200',
#   '제주특별자치도 서귀포시 성산읍 고성리 1201',
#   '33.452030373955964',
#   '126.91448341442346'],
#  ['제주 대명리조트',
#   '소노벨 제주',
#   '1588-4888',
#   '제주특별자치도 제주시 조천읍 함덕리 274',
#   '33.541376642880266',
#   '126.6716678612834'],
#  ['제주도맛집',
#   '우진해장국',
#   '064-757-3393',
#   '제주특별자치도 제주시 삼도이동 831',
#   '33.51151689656457',
#   '126.52000128027187'],
#  ['청초수물회&섭국 [신관]',
#   '청초수물회',
#   '033-635-5050',
#   '강원특별자치도 속초시 조양동 1555-1',
#   '38.19214711524039',
#   '128.5905399503119'],
#  ['속초 엄지네포장마차',
#   '엄지네포장마차 속초점',
#   '033-638-5559',
#   '강원특별자치도 속초시 중앙동 478-49',
#   '38.203049336827476',
#   '128.5917760658347'],
#  ['미영이네식당',
#   '미영이네',
#   '064-792-0077',
#   '제주특별자치도 서귀포시 대정읍 하모리 770-29',
#   '33.217732821842',
#   '126.249828956914'],
#  ['내츄럴케이',
#   '내츄럴케이',
#   '',
#   '제주특별자치도 제주시 일도이동 416-10',
#   '33.504596308081',
#   '126.542405237573'],
#  ['제주스럽닭',
#   '제주스럽닭 서귀중문점',
#   '064-738-0044',
#   '제주특별자치도 서귀포시 중문동 2140-16',
#   '33.25092172733954',
#   '126.42334467057498'],
#  ['바삭돈가스',
#   '바삭돈가스',
#   '064-748-6555',
#   '제주특별자치도 제주시 연동 1398-2',
#   '33.4812242739281',
#   '126.488224445142'],
#  ['새우조나단',
#   '조나단씨푸드',
#   '041-363-1777',
#   '충남 당진시 신평면 운정리 961-2',
#   '36.8913127576197',
#   '126.822648515777'],
#  ['대춘해장국',
#   '대춘해장국 본점',
#   '064-757-7456',
#   '제주특별자치도 제주시 도남동 380-2',
#   '33.48042109382529',
#   '126.52377283761113'],
#  ['금능샌드',
#   '금능샌드',
#   '064-796-8072',
#   '제주특별자치도 제주시 한림읍 금능리 1426-4',
#   '33.38922134655233',
#   '126.23246355983767'],
#  ['참맛나김밥',
#   '참맛나김밥',
#   '064-748-2654',
#   '제주특별자치도 제주시 노형동 3813-5',
#   '33.478588676811455',
#   '126.47501734137813'],
#  ['리치망고 협재점',
#   '리치망고 협재점',
#   '064-796-7729',
#   '제주특별자치도 제주시 한림읍 옹포리 596-2',
#   '33.402421378993665',
#   '126.2517821232083'],
#  ['가배',
#   '가배',
#   '',
#   '경기 양주시 장흥면 석현리 371-4',
#   '37.73817332179283',
#   '126.95186843563769'],
#  ['떡하니',
#   '떡하니',
#   '064-727-7080',
#   '제주특별자치도 제주시 이도2동 777-3',
#   '33.4909703721936',
#   '126.534376494097'],
#  ['듀블라썸',
#   '듀블라썸',
#   '',
#   '제주특별자치도 제주시 조천읍 조천리 2435',
#   '33.5390097038327',
#   '126.636399605678'],
#  ['카페오드리',
#   '카페오드리',
#   '0507-1451-4657',
#   '제주특별자치도 제주시 한림읍 금악리 1954-2',
#   '33.35698722317094',
#   '126.29725696442758'],
#  ['낙지로',
#   '낙지로',
#   '064-743-9363',
#   '제주특별자치도 제주시 연동 292-25',
#   '33.4886210266593',
#   '126.494395960969'],
#  ['일도전복',
#   '일도전복',
#   '064-753-0092',
#   '제주특별자치도 제주시 일도이동 109-17',
#   '33.49821695694911',
#   '126.54592331166398'],
#  ['대돈',
#   '대돈',
#   '064-757-7400',
#   '제주특별자치도 제주시 건입동 1399-1',
#   '33.5158651251043',
#   '126.52676040608'],
#  ['광원',
#   '광원',
#   '064-744-1000',
#   '제주특별자치도 제주시 노형동 75-1',
#   '33.4726484568945',
#   '126.484776330528'],
#  ['곰막 횟집',
#   '곰막식당',
#   '064-727-5111',
#   '제주특별자치도 제주시 구좌읍 동복리 667-1',
#   '33.55686867414115',
#   '126.72050964727606'],
#  ['부자식당',
#   '부자식당',
#   '061-666-8884',
#   '전남 여수시 종화동 589-1',
#   '34.738944724346',
#   '127.745811803173'],
#  ['곱을락',
#   '곱을락 경성부경대점',
#   '051-611-1067',
#   '부산 남구 대연동 33-27',
#   '35.1379240832755',
#   '129.104713810282'],
#  ['곽지스테이션',
#   '와인스테이션',
#   '',
#   '제주특별자치도 제주시 애월읍 신엄리 3063-1',
#   '33.467664763232',
#   '126.356555679763'],
#  ['교래 손 칼국수',
#   '교래손칼국수',
#   '064-782-9870',
#   '제주특별자치도 제주시 조천읍 교래리 491',
#   '33.43610297872',
#   '126.676080314629'],
#  ['사이카레',
#   '사이카레 제주애월본점',
#   '064-711-4279',
#   '제주특별자치도 제주시 애월읍 구엄리 509',
#   '33.4842446359284',
#   '126.381106668339'],
#  ['현대백화점 울산점',
#   '현대백화점 울산점',
#   '052-228-2233',
#   '울산 남구 삼산동 1521-1',
#   '35.5395950301785',
#   '129.33574650999'],
#  ['테디밸리골프리조트',
#   '테디밸리골프앤리조트',
#   '064-793-1000',
#   '제주특별자치도 서귀포시 안덕면 상창리 2893',
#   '33.292523254413204',
#   '126.34868128339699'],
#  ['제주중문관광단지',
#   '제주중문관광단지',
#   '064-739-1330',
#   '제주특별자치도 서귀포시 중문동 2624-1',
#   '33.2458352639585',
#   '126.420734158755'],
#  ['김포 구래동', '가마지천', '', '경기 김포시 구래동', '37.6507864852963', '126.634867756641'],
#  ['성산스쿠버리조트',
#   '성산스쿠버리조트',
#   '064-782-6117',
#   '제주특별자치도 서귀포시 성산읍 성산리 143-4',
#   '33.4609490766286',
#   '126.933565862831'],
#  ['흑송',
#   '흑송',
#   '051-704-9955',
#   '부산 해운대구 송정동 443-3',
#   '35.1750106256909',
#   '129.196512928977'],
#  ['제주시 새우리',
#   '제주시새우리 제주점',
#   '064-900-2527',
#   '제주특별자치도 제주시 삼도이동 1053-22',
#   '33.514612201433756',
#   '126.52073761952214'],
#  ['거멍국수',
#   '거멍국수',
#   '064-792-8787',
#   '제주특별자치도 서귀포시 안덕면 사계리 522-1',
#   '33.24437894131444',
#   '126.30440962206518'],
#  ['갈치왕',
#   '갈치왕 중문점',
#   '064-739-9333',
#   '제주특별자치도 서귀포시 상예동 1719-1',
#   '33.2646549136212',
#   '126.39076081925536'],
#  ['청춘게스트하우스',
#   '청춘게스트하우스',
#   '061-242-9921',
#   '전남 목포시 죽교동 236-4',
#   '34.79217506987312',
#   '126.37689450582724'],
#  ['OLD STUFF 올드스터프 Coffee&bread',
#   '올드스터프',
#   '070-8865-4511',
#   '전북특별자치도 전주시 완산구 효자동3가 1643-1',
#   '35.82320980062855',
#   '127.10222486275687'],
#  ['김녕해수욕장 (Gimnyeong Beach)',
#   '김녕해수욕장',
#   '064-728-3987',
#   '제주특별자치도 제주시 구좌읍 김녕리 497-4',
#   '33.5574388587079',
#   '126.759313988844'],
#  ['도깨비명당',
#   '도깨비명당',
#   '',
#   '경북 경주시 황남동 78',
#   '35.8365847379626',
#   '129.211804358419'],
#  ['맛있는 제주',
#   '맛있는제주',
#   '02-566-1226',
#   '서울 강남구 역삼동 699-2',
#   '37.50517295656051',
#   '127.04241492589169'],
#  ['자매국수 본점',
#   '자매국수',
#   '064-746-2222',
#   '제주특별자치도 제주시 이호일동 651-3',
#   '33.498577203781664',
#   '126.45914433997106'],
#  ['세영수산',
#   '세영수산',
#   '064-783-1913',
#   '제주특별자치도 서귀포시 성산읍 성산리 166-3',
#   '33.461038223460655',
#   '126.93169948452592'],
#  ['전주도',
#   '전주역',
#   '1544-7788',
#   '전북특별자치도 전주시 덕진구 우아동3가 235-10',
#   '35.8498531247183',
#   '127.16180338402'],
#  ['팔도수산식당',
#   '팔도수산식당',
#   '064-725-1181',
#   '제주특별자치도 제주시 건입동 1319-37',
#   '33.5166519767225',
#   '126.52787983828'],
#  ['사방팔방 외도점',
#   '사방팔방',
#   '064-743-4080',
#   '제주특별자치도 제주시 외도일동 494-5',
#   '33.4888984172137',
#   '126.429536827371'],
#  ['남원 포구',
#   '위미항',
#   '',
#   '제주특별자치도 서귀포시 남원읍',
#   '33.269920656371',
#   '126.661445396967'],
#  ['나원횟집',
#   '나원횟집',
#   '064-762-7878',
#   '제주특별자치도 서귀포시 서귀동 254-6',
#   '33.2497176227966',
#   '126.567457350132'],
#  ['대기정',
#   '대기정',
#   '064-739-1041',
#   '제주특별자치도 서귀포시 대포동 1787',
#   '33.2402922401071',
#   '126.428564629713'],
#  ['정관신도시',
#   '정관신도시',
#   '',
#   '부산 기장군 정관읍 용수리 141',
#   '35.325561130552',
#   '129.180299562099'],
#  ['경성대 맛집',
#   '김유순대구뽈찜전문',
#   '051-627-4319',
#   '부산 남구 대연동 291-2',
#   '35.1363540063858',
#   '129.091513709565'],
#  ['자연스러운식당',
#   '자연스러운식당',
#   '0507-1306-8702',
#   '제주특별자치도 서귀포시 호근동 1559-2',
#   '33.243399160632066',
#   '126.53261178663291'],
#  ['바다사랑그리고추억',
#   '바다사랑그리고추억',
#   '064-713-0110',
#   '제주특별자치도 제주시 애월읍 하귀2리 2740',
#   '33.4875623775152',
#   '126.390547450636'],
#  ['제주송정농원',
#   '제주송정농원',
#   '010-6358-2381',
#   '제주특별자치도 제주시 영평동 2470-5',
#   '33.480116134767826',
#   '126.56439963127046'],
#  ['제주 이자와',
#   '이자와 제주시청점',
#   '070-7856-4222',
#   '제주특별자치도 제주시 이도이동 1179-4',
#   '33.49883445507783',
#   '126.53065508548892'],
#  ['플레이스엉물',
#   '플레이스엉물',
#   '070-7787-1515',
#   '제주특별자치도 제주시 구좌읍 종달리 756',
#   '33.4896558980102',
#   '126.900660269856'],
#  ['한림 뽈살집',
#   '뽈살집 한림점',
#   '064-796-5860',
#   '제주특별자치도 제주시 한림읍 한림리 1252-8',
#   '33.415659816788725',
#   '126.26924845058332'],
#  ['덕승식당',
#   '덕승식당',
#   '064-794-0177',
#   '제주특별자치도 서귀포시 대정읍 하모리 770-3',
#   '33.2192664935737',
#   '126.251180315246'],
#  ['효섬마을 초가집',
#   '효섬마을초가집',
#   '064-725-7750',
#   '제주특별자치도 제주시 봉개동 234-161',
#   '33.4654544421006',
#   '126.611633933589'],
#  ['부촌식당',
#   '부촌식당',
#   '055-641-3308',
#   '경남 통영시 북신동 660-11',
#   '34.8559600403355',
#   '128.427852821257'],
#  ['담아래',
#   '담아래',
#   '064-738-5917',
#   '제주특별자치도 제주시 연동 1318-3',
#   '33.469381683532234',
#   '126.48731403845683'],
#  ['제주돈아',
#   '제주돈아 고내점',
#   '064-799-4491',
#   '제주특별자치도 제주시 애월읍 고내리 1214',
#   '33.4662983732359',
#   '126.334939486989'],
#  ['제주한라수목원♥',
#   '한라수목원',
#   '064-710-7575',
#   '제주특별자치도 제주시 연동 2484',
#   '33.4697839260314',
#   '126.493266082832'],
#  ['민경이네 어등포해녀촌',
#   '민경이네어등포해녀촌',
#   '064-782-7500',
#   '제주특별자치도 제주시 구좌읍 행원리 102',
#   '33.5537346764512',
#   '126.825773171122'],
#  ['Nolman',
#   '놀맨',
#   '064-799-3332',
#   '제주특별자치도 제주시 애월읍 애월리 2530',
#   '33.4624668172925',
#   '126.310224003017'],
#  ['사는맛 먹는맛',
#   '사는맛먹는맛',
#   '031-657-4845',
#   '경기 안성시 공도읍 용두리 682-11',
#   '36.9996274361574',
#   '127.154720475195'],
#  ['성산옥탑',
#   '제주옥탑 창원상남점',
#   '010-4302-6692',
#   '경남 창원시 성산구 상남동 4',
#   '35.2231248356246',
#   '128.68641549313'],
#  ['몽땅카페',
#   '프레쉬몽땅카페',
#   '',
#   '서울 강동구 암사동 439',
#   '37.5540653062041',
#   '127.1376162287'],
#  ['한라산버섯연구소',
#   '한라산버섯연구소',
#   '',
#   '제주특별자치도 서귀포시 중문동 산 1-3',
#   '33.3320090628383',
#   '126.45932954628'],
#  ['검은여식당',
#   '검은여식당',
#   '064-787-1104',
#   '제주특별자치도 서귀포시 표선면 표선리 1861',
#   '33.33684613300036',
#   '126.82787760353364'],
#  ['국수바다',
#   '국수바다 본점',
#   '064-739-9255',
#   '제주특별자치도 서귀포시 대포동 630',
#   '33.25299380456801',
#   '126.44720338391366'],
#  ['괜찮은술책',
#   '괜찮은술책',
#   '0507-1438-7224',
#   '제주특별자치도 제주시 구좌읍 종달리 1889-4',
#   '33.49254181395116',
#   '126.89504310602462'],
#  ['이어도전복해물전문점',
#   '이어도',
#   '064-733-0345',
#   '제주특별자치도 서귀포시 동홍동 393-9',
#   '33.2489662572046',
#   '126.570229561458'],
#  ['알동네국수',
#   '알동네국수',
#   '064-767-0555',
#   '제주특별자치도 서귀포시 하효동 1001',
#   '33.2508934221554',
#   '126.620505165467'],
#  ['강정포구',
#   '강정포구',
#   '',
#   '제주특별자치도 서귀포시 강정동 4965-1',
#   '33.2271155064362',
#   '126.475561352176'],
#  ['서귀포흑돼지명가',
#   '서귀포흑돼지명가',
#   '064-739-7347',
#   '제주특별자치도 서귀포시 호근동 431-8',
#   '33.2440442964123',
#   '126.536350990028'],
#  ['하림각',
#   '하림각',
#   '02-396-2442',
#   '서울 종로구 부암동 188',
#   '37.597080116362164',
#   '126.96272484746255'],
#  ['맥도날드장안사거리점',
#   '맥도날드 장안사거리점',
#   '070-7017-6857',
#   '서울 동대문구 장안동 308-4',
#   '37.5724638396628',
#   '127.072637595858'],
#  ['탕196',
#   '탕196',
#   '02-356-7752',
#   '경기 고양시 덕양구 용두동 432-378',
#   '37.62717902140011',
#   '126.89585191338027'],
#  ['제주마당',
#   '제주마당',
#   '064-749-5501',
#   '제주특별자치도 제주시 이호일동 663-1',
#   '33.49810414027896',
#   '126.45817446683485'],
#  ['형제섬', '형제섬', '', '경남 거제시 남부면', '34.7109149877063', '128.644665989846'],
#  ['동복해녀식당',
#   '동복해녀식당',
#   '064-783-4141',
#   '제주특별자치도 제주시 구좌읍 동복리 1647',
#   '33.553472573104635',
#   '126.70694723770639'],
#  ['종로 광장시장',
#   '광장시장',
#   '02-2267-0291',
#   '서울 종로구 예지동 2-1',
#   '37.570033672535104',
#   '126.9989416227693'],
#  ['디스이즈핫',
#   '디스이즈핫',
#   '',
#   '제주특별자치도 제주시 구좌읍 하도리 59-1',
#   '33.5131489720297',
#   '126.897326953126']]

# %%
# list -> DataFrame 변경
dfLocationResults = pd.DataFrame(locationResults)
dfLocationResults
# Out:
#                  0               1              2                         3  \
# 0             Jeju     R고기 in Jeju   064-744-6222   제주특별자치도 제주시 도두일동 2623-4
# 1         Seogwipo          서귀포잠수함   064-732-6060    제주특별자치도 서귀포시 서홍동 707-5
# 2    제주도 크리스마스 박물관  바이나흐튼 크리스마스박물관  010-4602-7976  제주특별자치도 서귀포시 안덕면 서광리 456
# 3             할로비치            할로비치                         서울 강남구 신사동 511-7
# 4          제주에인감귤밭         제주에인감귤밭                     제주특별자치도 서귀포시 호근동 693
# ..             ...             ...            ...                       ...
# 769           제주마당            제주마당   064-749-5501    제주특별자치도 제주시 이호일동 663-1
# 770            형제섬             형제섬                               경남 거제시 남부면
# 771         동복해녀식당          동복해녀식당   064-783-4141  제주특별자치도 제주시 구좌읍 동복리 1647
# 772        종로 광장시장            광장시장   02-2267-0291            서울 종로구 예지동 2-1
# 773          디스이즈핫           디스이즈핫                 제주특별자치도 제주시 구좌읍 하도리 59-1
#
#                       4                   5
# 0    33.503587560005954  126.46542934219148
# 1      33.2393033784206    126.558616052674
# 2     33.29131209935493  126.32779866033343
# 3      37.5182108620338    127.020825988861
# 4     33.25656069063887   126.5390139270361
# ..                  ...                 ...
# 769   33.49810414027896  126.45817446683485
# 770    34.7109149877063    128.644665989846
# 771  33.553472573104635  126.70694723770639
# 772  37.570033672535104   126.9989416227693
# 773    33.5131489720297    126.897326953126
#
# [774 rows x 6 columns]

# %%
dfLocationResults.columns = ['초기 이름', '실제 이름', '전화번호', '주소', '위도', '경도']

# %%
dfLocationResults.to_excel('./data/3_locations.xlsx', index=False)

# %% [markdown]
# ##### 인스타그램 크롤링 정보와 카카오 API로 주소 검색결과정보 병합

# %%
dfLocCounts.head()
# Out:
#                       count
# place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59

# %%
dfLocationResults.head()
# Out:
#            초기 이름           실제 이름           전화번호                        주소  \
# 0           Jeju     R고기 in Jeju   064-744-6222   제주특별자치도 제주시 도두일동 2623-4
# 1       Seogwipo          서귀포잠수함   064-732-6060    제주특별자치도 서귀포시 서홍동 707-5
# 2  제주도 크리스마스 박물관  바이나흐튼 크리스마스박물관  010-4602-7976  제주특별자치도 서귀포시 안덕면 서광리 456
# 3           할로비치            할로비치                         서울 강남구 신사동 511-7
# 4        제주에인감귤밭         제주에인감귤밭                     제주특별자치도 서귀포시 호근동 693
#
#                    위도                  경도
# 0  33.503587560005954  126.46542934219148
# 1    33.2393033784206    126.558616052674
# 2   33.29131209935493  126.32779866033343
# 3    37.5182108620338    127.020825988861
# 4   33.25656069063887   126.5390139270361

# %%
# reset_index로 place를 일반 컬럼으로 변경
dfLocCounts.reset_index(inplace=True)

# %%
dfLocCounts.head()
# Out:
#                   place  count
# 0                  Jeju    271
# 1               Jeju-do    179
# 2  Jungle Book by Alice    108
# 3              Seogwipo     66
# 4         제주도 크리스마스 박물관     59

# %%
locationData = pd.merge(left=dfLocationResults, right=dfLocCounts, how='inner', left_on='초기 이름', right_on='place')

# %%
locationData.tail()
# Out:
#        초기 이름   실제 이름          전화번호                        주소  \
# 769     제주마당    제주마당  064-749-5501    제주특별자치도 제주시 이호일동 663-1
# 770      형제섬     형제섬                              경남 거제시 남부면
# 771   동복해녀식당  동복해녀식당  064-783-4141  제주특별자치도 제주시 구좌읍 동복리 1647
# 772  종로 광장시장    광장시장  02-2267-0291            서울 종로구 예지동 2-1
# 773    디스이즈핫   디스이즈핫                제주특별자치도 제주시 구좌읍 하도리 59-1
#
#                      위도                  경도    place  count
# 769   33.49810414027896  126.45817446683485     제주마당      1
# 770    34.7109149877063    128.644665989846      형제섬      1
# 771  33.553472573104635  126.70694723770639   동복해녀식당      1
# 772  37.570033672535104   126.9989416227693  종로 광장시장      1
# 773    33.5131489720297    126.897326953126    디스이즈핫      1

# %%
# 중복 데이터 확인
locationData['실제 이름'].value_counts()
# Out:
# 실제 이름
# 제주동문시장                4
# 올레길 7코스(서귀포-월평 올레)    4
# 세화해변                  3
# 에코랜드테마파크              3
# 오설록 티뮤지엄              3
#                      ..
# 수제홍과일모찌 애월하귀점         1
# 대천해수욕장                1
# 도라지식당                 1
# 호박다방                  1
# 디스이즈핫                 1
# Name: count, Length: 708, dtype: int64

# %%
# 중복데이터 pivot
locationDataFinal = locationData.pivot_table(values='count', index=['실제 이름', '주소', '위도', '경도'], aggfunc='sum')

# %%
locationDataFinal.reset_index(inplace=True)

# %%
locationDataFinal.tail()
# Out:
#            실제 이름                         주소                위도  \
# 704    휴애리자연생활공원  제주특별자치도 서귀포시 남원읍 신례리 2081   33.309410458656
# 705  흑돼지가있는풍경 본점        제주특별자치도 제주시 노형동 668   33.475375671553
# 706           흑송          부산 해운대구 송정동 443-3  35.1750106256909
# 707  히든클리프호텔&네이쳐       제주특별자치도 서귀포시 상예동 625  33.2547764885257
# 708           히비        서울 용산구 원효로1가 128-12  37.5384855299872
#
#                    경도  count
# 704  126.635409752107     11
# 705  126.480646164645      1
# 706  129.196512928977      1
# 707  126.402595131766      9
# 708  126.968454416507      1

# %%
locationDataFinal.to_excel('./data/3_locations_final.xlsx')

# %%
locationDataFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   실제 이름   709 non-null    object
#  1   주소      709 non-null    object
#  2   위도      709 non-null    object
#  3   경도      709 non-null    object
#  4   count   709 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 27.8+ KB

# %%
# 위도, 경도가 object에서 float64로 변경
locationDataFinal = locationDataFinal.astype({'위도':'float64', '경도':'float64'})

# %%
locationDataFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   실제 이름   709 non-null    object
#  1   주소      709 non-null    object
#  2   위도      709 non-null    float64
#  3   경도      709 non-null    float64
#  4   count   709 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 27.8+ KB

# %% [markdown]
# ##### 지도 시각화
# - folium 사용

# %%
locHanlaMt = [33.362050, 126.530087]
map = folium.Map(location=locHanlaMt, zoom_start=11)

for i in range(len(locationDataFinal)):
    name = locationDataFinal['실제 이름'][i] # DF 컬럼이름 행값 == i
    count = int(locationDataFinal['count'][i])
    lat = float(locationDataFinal['위도'][i])
    lng = float(locationDataFinal['경도'][i])
    folium.CircleMarker(location=[lat, lng], radius=count, color='orange', popup=name).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82c5a2afc8a1965bcb42e845f76d0ff3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82c5a2afc8a1965bcb42e845f76d0ff3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82c5a2afc8a1965bcb42e845f76d0ff3 = L.map(
#                 &quot;map_82c5a2afc8a1965bcb42e845f76d0ff3&quot;,
#                 {
#                     center: [33.36205, 126.530087],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c67a46040ccf8c67a521d8220f9ea830 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c67a46040ccf8c67a521d8220f9ea830.addTo(map_82c5a2afc8a1965bcb42e845f76d0ff3);
#
#
#             var circle_marker_537cfe5cef1d61c7f20a261ec191917a = L.circleMarker(
#                 [33.46707849152644, 126.33649979086103],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82c5a2afc8a1965bcb42e845f76d0ff3);
#
#
#         var popup_ddbddc276209f1b2dbeabf2ee9b4cb91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b8d473cb25d154d2c3976eedeed982b = $(`&lt;div id=&quot;html_6b8d473cb25d154d2c3976eedeed982b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1158족욕카페&lt;/div&gt;`)[0];
#                 popup_ddbddc276209f1b2dbeabf2ee9b4cb91.setContent(html_6b8d473cb25d154d2c3976eedeed982b);
#
#
#
#         circle_marker_537cfe5cef1d61c7f20a261ec191917a.bindPopup(popup_ddbddc276209f1b2dbeabf2ee9b4cb91)
#         ;
#
#
#
#
#             var circle_marker_717b58fa7753b42930202801d30939ac = L.circleMarker(
#                 [33.45699074238026, 126.45510883544576],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82c5a2afc8a1965bcb42e845f76d0ff3);
#
#
#         var popup_6e16ad1237e5d4a4a365c075f4cd9706 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ecd05245779ebabc1bcd8bb4a12e989 = $(`&lt;div id=&quot;html_3ecd05245779ebabc1bcd8bb4a12e989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;73st&lt;/div&gt;`)[0];
#                 popup_6e16ad1237e5d4a4a365c075f4cd9706.setContent(html_3ecd05245779ebabc1bcd8bb4a12e989);
#
#
#
#         circle_marker_717b58fa7753b42930202801d30939ac.bindPopup(popup_6e16ad1237e5d4a4a365c075f4cd9706)
#         ;
#
#
#
#
#             var circle_marker_ca4ff692784ffb4a86d4fd84d061624a = L.circleMarker(
#                 [37.26812040180812, 127.000144309653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82c5a2afc8a1965bcb42e845f76d0ff3);
#
#
#         var popup_ba16bea4148195c0e595ad172a31e5b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c32049df5cb38474e0a91ecfb4356360 = $(`&lt;div id=&quot;html_c32049df5cb38474e0a91ecfb4356360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CU 수원광장점&lt;/div&gt;`)[0];
#                 popup_ba16bea4148195c0e595ad172a31e5b5.setContent(html_c32049df5cb38474e0a91ecfb4356360);
#
#
#
#         circle_marker_ca4ff692784ffb4a86d4fd84d061624a.bindPopup(popup_ba16bea4148195c0e595ad172a31e5b5)
#         ;
#
#
#
#
#             var circle_marker_1a86723b01c834cd4e3ea85ab597141d = L.circleMarker(
#                 [37.52470211311498, 126.91674992301569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quo

# %%
map.save('./data/3_jeju_hotplaces.html')

# %%
# 마커 클러스터
mapLocs = []
mapNames = []

for i in range(len(locationDataFinal)): # 709번 반복
    data = locationDataFinal.iloc[i]    # 행 하나씩 읽어옴
    mapLocs.append((float(data['위도']), float(data['경도'])))
    mapNames.append(data['실제 이름'])

locHanlaMt = [33.362050, 126.530087]
map = folium.Map(location=locHanlaMt, zoom_start=11)

markerCluster = MarkerCluster(locations=mapLocs, popups=mapNames, name='제주 핫플레이스', overlay=True, control=True)
markerCluster.add_to(map)
folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7330aecce09f156c5aefe7f89a6b977 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7330aecce09f156c5aefe7f89a6b977&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7330aecce09f156c5aefe7f89a6b977 = L.map(
#                 &quot;map_c7330aecce09f156c5aefe7f89a6b977&quot;,
#                 {
#                     center: [33.36205, 126.530087],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82d2ff6c094f924f10ca332e1153ba86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82d2ff6c094f924f10ca332e1153ba86.addTo(map_c7330aecce09f156c5aefe7f89a6b977);
#
#
#             var marker_cluster_fe49e167b665ef05f008019690be19fa = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_1d8c9bbb8531af7ed9fa2745b67ba5a9 = L.marker(
#                 [33.46707849152644, 126.33649979086103],
#                 {}
#             ).addTo(marker_cluster_fe49e167b665ef05f008019690be19fa);
#
#
#         var popup_4c3b4fa62bfcf769ec20f2f61db07dad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6e5119670fad07da1b34efa9d86d152 = $(`&lt;div id=&quot;html_b6e5119670fad07da1b34efa9d86d152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1158족욕카페&lt;/div&gt;`)[0];
#                 popup_4c3b4fa62bfcf769ec20f2f61db07dad.setContent(html_b6e5119670fad07da1b34efa9d86d152);
#
#
#
#         marker_1d8c9bbb8531af7ed9fa2745b67ba5a9.bindPopup(popup_4c3b4fa62bfcf769ec20f2f61db07dad)
#         ;
#
#
#
#
#             var marker_a688ff8a3260224756c32d7042d17c3e = L.marker(
#                 [33.45699074238026, 126.45510883544576],
#                 {}
#             ).addTo(marker_cluster_fe49e167b665ef05f008019690be19fa);
#
#
#         var popup_5ad8847666ba49975651ca37e2d562f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f8fae67f2faf66c48ae400964f4d23e = $(`&lt;div id=&quot;html_0f8fae67f2faf66c48ae400964f4d23e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;73st&lt;/div&gt;`)[0];
#                 popup_5ad8847666ba49975651ca37e2d562f4.setContent(html_0f8fae67f2faf66c48ae400964f4d23e);
#
#
#
#         marker_a688ff8a3260224756c32d7042d17c3e.bindPopup(popup_5ad8847666ba49975651ca37e2d562f4)
#         ;
#
#
#
#
#             var marker_e2f31b0dfbaf4b8ff7a8d21ac4586458 = L.marker(
#                 [37.26812040180812, 127.000144309653],
#                 {}
#             ).addTo(marker_cluster_fe49e167b665ef05f008019690be19fa);
#
#
#         var popup_cf9cb2171f85476149659775d899f808 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1195a466d230018c87ed559a7da7c814 = $(`&lt;div id=&quot;html_1195a466d230018c87ed559a7da7c814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CU 수원광장점&lt;/div&gt;`)[0];
#                 popup_cf9cb2171f85476149659775d899f808.setContent(html_1195a466d230018c87ed559a7da7c814);
#
#
#
#         marker_e2f31b0dfbaf4b8ff7a8d21ac4586458.bindPopup(popup_cf9cb2171f85476149659775d899f808)
#         ;
#
#
#
#
#             var marker_4b623a5c10a8e17745cc33f1fb77208d = L.marker(
#                 [37.52470211311498, 126.91674992301569],
#                 {}
#             ).addTo(marker_cluster_fe49e167b665ef05f008019690be19fa);
#
#
#         var popup_6e76e7652ae276e649a27d15f79a0587 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_155322272546fd98fa5c9ef1980ad876 = $(`&lt;div id=&quot;html_155322272546fd98fa5c9ef1980ad876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KBS 본관&lt;/div&gt;`)[0];
#                 popup_6e76e7652ae276e649a27d15f79a0587.setContent(html_155322272546fd98fa5c9ef1980ad876);
#
#
#
#         marker_4b623a5c10a8e17745cc33f1fb77208d.bindPopup(popup_6e76e7652ae276e649a27d15f79a0587)
#         ;
#
#
#
#
#             var marker_f48b97c463789a251e1ffca1ac68a1c3 = L.marker(
#                 [36.7814052783056, 126.456420317236],
#                 {}
#             ).addTo(marker_cluster_fe49e167b665ef05f008019690be19fa);
#
#
#         var popup_e89ec1dfd182ce3794da6b1c2480a88f = L.popup({&quot;maxWidth&quot;: &quot;100%&

# %%
map.save('./data/3_jeju_hotplaces_cluster.html')
